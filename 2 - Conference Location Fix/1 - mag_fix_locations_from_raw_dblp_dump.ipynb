# %% [markdown]
# # Fix the Missing MAG Conferences Location Using the DBLP Raw Dump
#
# Jupyter Notebook for adding the conferences locations of DBLP.
#
# For this process, the following CSV files are needed: ```out_dblp_raw_proceedings.csv``` and ```out_mag_citations_count_and_conferences.csv```. <br>
# The first file must be generated following the instructions cointained in the ```preprocess_dblp.ipynb``` Notebook, that is contained in the ```1 - Citation Dumps Preprocess``` folder of this Repository.<br>
# The second one must be generated running the ```preprocess_mag.ipynb``` Notebook that is contained in the ```1 - Citation Dumps Preprocess``` folder of this Repository.
#
# In particular, the following operations are going to be executed:
# * Opening of the CSV preprocessed dump
# * Opening of the proceedings raw dump
# * Obtaining the locations from the proceedings raw dump
#
# Lastly, the entire preprocessed dump is going to be saved on disk in CSV format

# %%
# Libraries Import
import pandas as pd
import spacy
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Download of the Spacy Pipelines
# Before getting started, be sure to download the Spacy Pipelines that is needed for the NLP operations.
#
# You can do so by running the following command in a Python shell: ```python -m spacy download en_core_web_lg```

# %% [markdown]
# ## File Paths
# Please set your working directory paths.

# %%
# ******************* PATHS ********************+

# Dumps Directory Path
path_file_import = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Import/'

# CSV Exports Directory Path
path_file_export = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/'

# %% [markdown]
# ## Read of the CSV Preprocessed Dump

# %%
df_mag = pd.read_csv(path_file_export + 'out_mag_citations_count_and_conferences.csv', low_memory=False, index_col=[0])

# Column sort
df_mag = df_mag.reindex(sorted(df_mag.columns), axis=1)

df_mag
# Out:
#          CitationCount ConferenceDisplayName  ConferenceInstanceID  \
# 0                   12             DISC 2014             4038532.0
# 1                   10              ESA 2014           157008481.0
# 2                   20                   NaN                   NaN
# 3                    0                   NaN                   NaN
# 4                   19                   NaN                   NaN
# ...                ...                   ...                   ...
# 4409811              0                   NaN                   NaN
# 4409812              0                   NaN                   NaN
# 4409813              0                   NaN                   NaN
# 4409814              0                   NaN                   NaN
# 4409815              0                   NaN                   NaN
#
#         ConferenceLocation ConferenceNormalizedName  \
# 0               Austin, TX                disc 2014
# 1          Wrocław, Poland                 esa 2014
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 4409811                NaN                      NaN
# 4409812                NaN                      NaN
# 4409813                NaN                      NaN
# 4409814                NaN                      NaN
# 4409815                NaN                      NaN
#
#                                ConferenceSeriesDisplayName  \
# 0         International Symposium on Distributed Computing
# 1                         European Symposium on Algorithms
# 2        Information and Communication Technologies in ...
# 3                 Database and Expert Systems Applications
# 4        International Conference on Artificial Intelli...
# ...                                                    ...
# 4409811   Conference of the Industrial Electronics Society
# 4409812  International Symposium on Broadband Multimedi...
# 4409813                        American Control Conference
# 4409814  International Conference on Acoustics, Speech,...
# 4409815  International Conference on Information Techno...
#
#          ConferenceSeriesID ConferenceSeriesNormalizedName  \
# 0              1.131603e+09                           DISC
# 1              1.154039e+09                            ESA
# 2              1.196984e+09                          ENTER
# 3              1.192665e+09                           DEXA
# 4              1.176896e+09                         ICAISC
# ...                     ...                            ...
# 4409811        2.623572e+09                          IECON
# 4409812        2.623662e+09                           BMSB
# 4409813        2.238538e+09                            ACC
# 4409814        1.121228e+09                         ICASSP
# 4409815        2.622834e+09                           ICIT
#
#                                      Doi  EstimatedCitation  \
# 0           10.1007/978-3-662-45174-8_28                 12
# 1           10.1007/978-3-662-44777-2_60                 10
# 2           10.1007/978-3-319-03973-2_13                 20
# 3               10.1007/3-540-46146-9_77                  0
# 4                    10.1007/11785231_94                 19
# ...                                  ...                ...
# 4409811  10.1109/IECON43393.2020.9254316                  0
# 4409812   10.1109/BMSB49480.2020.9379806                  0
# 4409813         10.1109/ACC.1988.4172843                  0
# 4409814      10.1109/ICASSP.2002.1005676                  0
# 4409815     10.1109/ITCA52113.2020.00077                  0
#
#                                              OriginalTitle     PaperID  \
# 0        The Adaptive Priority Queue with Elimination a...    14558443
# 1             Document Retrieval on Repetitive Collections    15354235
# 2                  SoCoMo Marketing for Travel and Tourism    24327294
# 3        Similarity Image Retrieval System Using Hierar...    60437532
# 4        Leukemia prediction from gene expression data—...   198056957
# ...                                                    ...         ...
# 4409811  Loss Reduction by Synchronous Rectification in...  3102242761
# 4409812  Data Over Cable Services – Improving the BICM ...  3136855299
# 4409813  Model Reference Robust Adaptive Control withou...  3145351916
# 4409814  Missing data speech recognition in reverberant...  3151696876
# 4409815  Research on Text to Image Based on Generative ...  3162646375
#
#                                                 PaperTitle  Year
# 0        the adaptive priority queue with elimination a...  2014
# 1             document retrieval on repetitive collections  2014
# 2                  socomo marketing for travel and tourism  2013
# 3        similarity image retrieval system using hierar...  2002
# 4        leukemia prediction from gene expression data ...  2006
# ...                                                    ...   ...
# 4409811  loss reduction by synchronous rectification in...  2020
# 4409812  data over cable services improving the bicm ca...  2020
# 4409813  model reference robust adaptive control withou...  1988
# 4409814  missing data speech recognition in reverberant...  2002
# 4409815  research on text to image based on generative ...  2020
#
# [4409812 rows x 14 columns]

# %% [markdown]
# ## Read of the Proceedings CSV

# %%
df_dblp_proceedings = pd.read_csv(path_file_import + 'out_dblp_raw_proceedings.csv', low_memory=False, sep=";")
df_dblp_proceedings
# Out:
#             id address author           booktitle cite cite-label  \
# 0        90858     NaN    NaN                 NaN  NaN        NaN
# 1       109806     NaN    NaN                 NaN  NaN        NaN
# 2      3062827     NaN    NaN                 OTM  NaN        NaN
# 3      3062933     NaN    NaN   CoopIS/DOA/ODBASE  NaN        NaN
# 4      3062955     NaN    NaN              CoopIS  NaN        NaN
# ...        ...     ...    ...                 ...  ...        ...
# 50207  8958161     NaN    NaN                 NaN  NaN        NaN
# 50208  8958192     NaN    NaN                 NaN  NaN        NaN
# 50209  8958224     NaN    NaN                 NaN  NaN        NaN
# 50210  8958650     NaN    NaN               PT-AI  NaN        NaN
# 50211  8960537     NaN    NaN  MMB (Kurzvorträge)  NaN        NaN
#
#                                                   editor  \
# 0      Amir Hossein Alavi|Amir Hossein Gandomi|Conor ...
# 1                              Ankur Agarwal|Borko Furht
# 2          Douglas C. Schmidt|Robert Meersman|Zahir Tari
# 3                             Robert Meersman|Zahir Tari
# 4      Carlo Batini|Fausto Giunchiglia|Massimo Mecell...
# ...                                                  ...
# 50207                          Rudi Studer|Steffen Staab
# 50208                    Jan vom Brocke|Michael Rosemann
# 50209                    Jan vom Brocke|Michael Rosemann
# 50210                                  Vincent C. Müller
# 50211      Dieter Baum|Norbert Th. Müller|Richard Rödler
#
#                                             editor-orcid  \
# 0      0000-0002-2798-0104|0000-0002-7002-5815|0000-0...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 50207                                                NaN
# 50208                                                NaN
# 50209                                                NaN
# 50210                                0000-0002-4144-4957
# 50211                                                NaN
#
#                                                       ee ee-type    i  \
# 0              https://doi.org/10.1007/978-3-319-20883-1     NaN  NaN
# 1              https://doi.org/10.1007/978-1-4614-8495-0     NaN  NaN
# 2                         https://doi.org/10.1007/b94348     NaN  NaN
# 3                        https://doi.org/10.1007/b102176     NaN  NaN
# 4                  https://doi.org/10.1007/3-540-44751-2     NaN  NaN
# ...                                                  ...     ...  ...
# 50207  https://doi.org/10.1007/978-3-540-92673-3|http...     NaN  NaN
# 50208          https://doi.org/10.1007/978-3-642-45100-3     NaN  NaN
# 50209          https://doi.org/10.1007/978-3-642-45103-4     NaN  NaN
# 50210          https://doi.org/10.1007/978-3-642-31674-6     NaN  NaN
# 50211                                                NaN     NaN  NaN
#
#                                       isbn isbn-type journal  \
# 0                        978-3-319-20882-4       NaN     NaN
# 1                        978-1-4614-8494-3       NaN     NaN
# 2                            3-540-20498-9       NaN     NaN
# 3                            3-540-23662-7       NaN     NaN
# 4                            3-540-42524-1       NaN     NaN
# ...                                    ...       ...     ...
# 50207  978-3-540-70999-2|978-3-540-92673-3       NaN     NaN
# 50208  978-3-642-45099-0|978-3-642-45100-3       NaN     NaN
# 50209  978-3-642-45102-7|978-3-642-45103-4       NaN     NaN
# 50210                    978-3-642-31673-9       NaN     NaN
# 50211                                  NaN       NaN     NaN
#
#                           key       mdate note note-type number pages  \
# 0      reference/genetic/2015  2020-03-27  NaN       NaN    NaN   NaN
# 1          reference/med/2013  2017-05-16  NaN       NaN    NaN   NaN
# 2            conf/coopis/2003  2021-04-30  NaN       NaN    NaN   NaN
# 3          conf/coopis/2004-2  2019-05-14  NaN       NaN    NaN   NaN
# 4            conf/coopis/2001  2019-05-14  NaN       NaN    NaN   NaN
# ...                       ...         ...  ...       ...    ...   ...
# 50207     series/ihis/2009hoo  2018-11-14  NaN       NaN    NaN   NaN
# 50208    series/ihis/2015bpm1  2017-05-16  NaN       NaN    NaN   NaN
# 50209    series/ihis/2015bpm2  2017-05-16  NaN       NaN    NaN   NaN
# 50210    series/sapere/2013-5  2019-09-06  NaN       NaN    NaN   NaN
# 50211        tr/trier/MI99-17  2019-09-07  NaN       NaN    NaN   NaN
#
#       publisher publisher-href  publtype school  \
# 0      Springer            NaN       NaN    NaN
# 1      Springer            NaN       NaN    NaN
# 2      Springer            NaN       NaN    NaN
# 3      Springer            NaN       NaN    NaN
# 4      Springer            NaN       NaN    NaN
# ...         ...            ...       ...    ...
# 50207  Springer            NaN       NaN    NaN
# 50208  Springer            NaN       NaN    NaN
# 50209  Springer            NaN       NaN    NaN
# 50210  Springer            NaN       NaN    NaN
# 50211       NaN            NaN  informal    NaN
#
#                                                   series  \
# 0                                                    NaN
# 1                                                    NaN
# 2                      Lecture Notes in Computer Science
# 3                      Lecture Notes in Computer Science
# 4                      Lecture Notes in Computer Science
# ...                                                  ...
# 50207     International Handbooks on Information Systems
# 50208     International Handbooks on Information Systems
# 50209     International Handbooks on Information Systems
# 50210  Studies in Applied Philosophy, Epistemology an...
# 50211  Universität Trier, Mathematik/Informatik, Fors...
#
#                        series-href  sub  sup  \
# 0                              NaN  NaN  NaN
# 1                              NaN  NaN  NaN
# 2        db/series/lncs/index.html  NaN  NaN
# 3        db/series/lncs/index.html  NaN  NaN
# 4        db/series/lncs/index.html  NaN  NaN
# ...                            ...  ...  ...
# 50207    db/series/ihis/index.html  NaN  NaN
# 50208    db/series/ihis/index.html  NaN  NaN
# 50209    db/series/ihis/index.html  NaN  NaN
# 50210  db/series/sapere/index.html  NaN  NaN
# 50211                          NaN  NaN  NaN
#
#                                                    title  \
# 0           Handbook of Genetic Programming Applications
# 1        Handbook of Medical and Healthcare Technologies
# 2      On The Move to Meaningful Internet Systems 200...
# 3      On the Move to Meaningful Internet Systems 200...
# 4      Cooperative Information Systems, 9th Internati...
# ...                                                  ...
# 50207                             Handbook on Ontologies
# 50208  Handbook on Business Process Management 1, Int...
# 50209  Handbook on Business Process Management 2, Str...
# 50210  Philosophy and Theory of Artificial Intelligen...
# 50211  MMB '99, Messung, Modellierung und Bewertung v...
#
#                                          url volume  year
# 0      db/reference/genetic/genetic2015.html    NaN  2015
# 1              db/reference/med/med2013.html    NaN  2013
# 2             db/conf/coopis/coopis2003.html   2888  2003
# 3           db/conf/coopis/coopis2004-2.html   3291  2004
# 4             db/conf/coopis/coopis2001.html   2172  2001
# ...                                      ...    ...   ...
# 50207            db/series/ihis/hoo2009.html    NaN  2009
# 50208          db/series/ihis/bpm2015-1.html    NaN  2015
# 50209          db/series/ihis/bpm2015-2.html    NaN  2015
# 50210          db/series/sapere/sapere5.html      5  2013
# 50211                db/conf/mmb/mmb99k.html  99-16  1999
#
# [50212 rows x 32 columns]

# %% [markdown]
# Here the main useless columns are going to be removed from the dataframe.

# %%
df_dblp_proceedings = df_dblp_proceedings.drop(columns=['address', 'author', 'booktitle', 'cite', 'cite-label', 'editor', 'editor-orcid', 'ee-type', 'i', 'isbn', 'isbn-type', 'journal', 'mdate', 'note', 'note-type', 'number', 'pages', 'publisher', 'publisher-href', 'publtype', 'school', 'sub', 'sup', 'volume'])
df_dblp_proceedings.loc[0:3]
# Out:
#         id                                         ee                     key  \
# 0    90858  https://doi.org/10.1007/978-3-319-20883-1  reference/genetic/2015
# 1   109806  https://doi.org/10.1007/978-1-4614-8495-0      reference/med/2013
# 2  3062827             https://doi.org/10.1007/b94348        conf/coopis/2003
# 3  3062933            https://doi.org/10.1007/b102176      conf/coopis/2004-2
#
#                               series                series-href  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2  Lecture Notes in Computer Science  db/series/lncs/index.html
# 3  Lecture Notes in Computer Science  db/series/lncs/index.html
#
#                                                title  \
# 0       Handbook of Genetic Programming Applications
# 1    Handbook of Medical and Healthcare Technologies
# 2  On The Move to Meaningful Internet Systems 200...
# 3  On the Move to Meaningful Internet Systems 200...
#
#                                      url  year
# 0  db/reference/genetic/genetic2015.html  2015
# 1          db/reference/med/med2013.html  2013
# 2         db/conf/coopis/coopis2003.html  2003
# 3       db/conf/coopis/coopis2004-2.html  2004

# %% [markdown]
# ## Fix of the Missing Conferences Names
# Some papers have only the indication of the conference series. For this reason, the conference instance and the related conference locations don't have a value.
#
# However, every paper has been published in a specific "instance" of a conference, hence it should have a location. These papers will be "fixed" considering the year of their publication and their conference.

# %%
df_mag_subset = df_mag.iloc[:50]
df_mag_subset = df_mag.dropna(subset = ['ConferenceNormalizedName'])
df_mag_subset.iloc[:10][["Year", "ConferenceSeriesNormalizedName", "ConferenceNormalizedName", "ConferenceDisplayName"]]
# Out:
#     Year ConferenceSeriesNormalizedName ConferenceNormalizedName  \
# 0   2014                           DISC                disc 2014
# 1   2014                            ESA                 esa 2014
# 7   2011                            LTC                 ltc 2011
# 8   2013                           CVPR                cvpr 2013
# 14  2008                           BMSB                bmsb 2008
# 16  2000                            CAV                 cav 2000
# 19  2008                           ISVC                isvc 2008
# 25  2000                           CLEO                cleo 2000
# 33  2014                            ICC                 icc 2014
# 35  2000                         CRYPTO              crypto 2000
#
#    ConferenceDisplayName
# 0              DISC 2014
# 1               ESA 2014
# 7               LTC 2011
# 8              CVPR 2013
# 14             BMSB 2008
# 16              CAV 2000
# 19             ISVC 2008
# 25             CLEO 2000
# 33              ICC 2014
# 35           CRYPTO 2000

# %% [markdown]
# As you can see in the above test, the ConferenceNormalizedName seems to be made by the concatenation of ConferenceSeriesNormalizedName in lowercase, a space, and the papers' year.
#
# **Note**: in the above subset the ConferenceDisplayName seems to be composed in the same way of ConferenceNormalizedName, but without the lowercase. However, this is not always true!
#
# Now we're going to populate the ConferenceNormalizedName instances that don't have a value.

# %%
df_mag.ConferenceNormalizedName.fillna(df_mag.ConferenceSeriesNormalizedName.str.lower() + ' ' + df_mag.Year.astype(str), inplace=True)
df_mag.iloc[:5]
# Out:
#    CitationCount ConferenceDisplayName  ConferenceInstanceID  \
# 0             12             DISC 2014             4038532.0
# 1             10              ESA 2014           157008481.0
# 2             20                   NaN                   NaN
# 3              0                   NaN                   NaN
# 4             19                   NaN                   NaN
#
#   ConferenceLocation ConferenceNormalizedName  \
# 0         Austin, TX                disc 2014
# 1    Wrocław, Poland                 esa 2014
# 2                NaN               enter 2013
# 3                NaN                dexa 2002
# 4                NaN              icaisc 2006
#
#                          ConferenceSeriesDisplayName  ConferenceSeriesID  \
# 0   International Symposium on Distributed Computing        1.131603e+09
# 1                   European Symposium on Algorithms        1.154039e+09
# 2  Information and Communication Technologies in ...        1.196984e+09
# 3           Database and Expert Systems Applications        1.192665e+09
# 4  International Conference on Artificial Intelli...        1.176896e+09
#
#   ConferenceSeriesNormalizedName                           Doi  \
# 0                           DISC  10.1007/978-3-662-45174-8_28
# 1                            ESA  10.1007/978-3-662-44777-2_60
# 2                          ENTER  10.1007/978-3-319-03973-2_13
# 3                           DEXA      10.1007/3-540-46146-9_77
# 4                         ICAISC           10.1007/11785231_94
#
#    EstimatedCitation                                      OriginalTitle  \
# 0                 12  The Adaptive Priority Queue with Elimination a...
# 1                 10       Document Retrieval on Repetitive Collections
# 2                 20            SoCoMo Marketing for Travel and Tourism
# 3                  0  Similarity Image Retrieval System Using Hierar...
# 4                 19  Leukemia prediction from gene expression data—...
#
#      PaperID                                         PaperTitle  Year
# 0   14558443  the adaptive priority queue with elimination a...  2014
# 1   15354235       document retrieval on repetitive collections  2014
# 2   24327294            socomo marketing for travel and tourism  2013
# 3   60437532  similarity image retrieval system using hierar...  2002
# 4  198056957  leukemia prediction from gene expression data ...  2006

# %% [markdown]
# I tried to do a new merge with the Conference Instances dataframe (this time it will be made on the ConferenceNormalizedName column), but I had no luck: these conference instances are missing. That's probably the reason of the NaN values in the ConferenceInstanceID field of the original Papers table.

# %% [markdown]
# Drop of the Conference Display Name column:

# %%
df_mag = df_mag.drop(columns=['ConferenceDisplayName'])

# %% [markdown]
# ## Drop of the ID Columns from the MAG Dataframe
# These columns are not needed anymore, since they were needed only for the join operations between the MAG tables.

# %%
df_mag = df_mag.drop(columns=['ConferenceInstanceID', 'ConferenceSeriesID', 'PaperID'])
df_mag.loc[0:3]
# Out:
#    CitationCount ConferenceLocation ConferenceNormalizedName  \
# 0             12         Austin, TX                disc 2014
# 1             10    Wrocław, Poland                 esa 2014
# 2             20                NaN               enter 2013
# 3              0                NaN                dexa 2002
#
#                          ConferenceSeriesDisplayName  \
# 0   International Symposium on Distributed Computing
# 1                   European Symposium on Algorithms
# 2  Information and Communication Technologies in ...
# 3           Database and Expert Systems Applications
#
#   ConferenceSeriesNormalizedName                           Doi  \
# 0                           DISC  10.1007/978-3-662-45174-8_28
# 1                            ESA  10.1007/978-3-662-44777-2_60
# 2                          ENTER  10.1007/978-3-319-03973-2_13
# 3                           DEXA      10.1007/3-540-46146-9_77
#
#    EstimatedCitation                                      OriginalTitle  \
# 0                 12  The Adaptive Priority Queue with Elimination a...
# 1                 10       Document Retrieval on Repetitive Collections
# 2                 20            SoCoMo Marketing for Travel and Tourism
# 3                  0  Similarity Image Retrieval System Using Hierar...
#
#                                           PaperTitle  Year
# 0  the adaptive priority queue with elimination a...  2014
# 1       document retrieval on repetitive collections  2014
# 2            socomo marketing for travel and tourism  2013
# 3  similarity image retrieval system using hierar...  2002

# %% [markdown]
# ## Extraction of the Conference Location from the Proceeding Title
#
# Adding the location column to the proceedings dataframe:

# %%
df_dblp_proceedings['ConferenceLocation'] = np.nan

# %% [markdown]
# Make sure the indexes are in pair with number of rows

# %%
df_dblp_proceedings = df_dblp_proceedings.reset_index()

# %% [markdown]
# Extraction of the locations using Spacy:

# %%
nlp = spacy.load("en_core_web_lg")

for index, row in df_dblp_proceedings.iterrows():
    doc = nlp(row['title'])

    conf_location = ""
    for ent in doc.ents:
        if ent.label_ == "GPE":
            if conf_location.__len__() != 0:
                conf_location += ", "
            conf_location += ent.text
        
        #print(ent.text, ent.label_) # TODO DEBUG

    if conf_location.__len__() == 0: # no location found
        conf_location = np.nan
    
    df_dblp_proceedings.at[index, 'ConferenceLocation'] = conf_location

    #print(f"{row['title']} --- Extracted Location: {conf_location}\n\n") # TODO DEBUG

# %% [markdown]
# Count of how many proceedings locations are still missing:

# %%
n_missing = len(df_dblp_proceedings.index) - len(df_dblp_proceedings.dropna(subset = ['ConferenceLocation']).index)
print(f"{n_missing} missing paper's conference locations")
# Out:
# 2105 missing paper's conference locations

# %% [markdown]
# ## Removing the Proceedings Data that We Don't Need Anymore

# %% [markdown]
# Here the rest of the useless columns are going to be removed from the dataframe.

# %%
df_dblp_proceedings = df_dblp_proceedings.drop(columns=['id', 'key', 'series', 'series-href', 'ee'])
df_dblp_proceedings.loc[0:3]
# Out:
#    index                                              title  \
# 0      0       Handbook of Genetic Programming Applications
# 1      1    Handbook of Medical and Healthcare Technologies
# 2      2  On The Move to Meaningful Internet Systems 200...
# 3      3  On the Move to Meaningful Internet Systems 200...
#
#                                      url  year      ConferenceLocation
# 0  db/reference/genetic/genetic2015.html  2015                     NaN
# 1          db/reference/med/med2013.html  2013                     NaN
# 2         db/conf/coopis/coopis2003.html  2003  Catania, Sicily, Italy
# 3       db/conf/coopis/coopis2004-2.html  2004                     NaN

# %% [markdown]
# Filtering the Proceedings without the location:

# %%
df_dblp_proceedings = df_dblp_proceedings.dropna(subset = ['ConferenceLocation'])
df_dblp_proceedings = df_dblp_proceedings.drop(columns=['index'])
df_dblp_proceedings
# Out:
#                                                    title  \
# 2      On The Move to Meaningful Internet Systems 200...
# 4      Cooperative Information Systems, 9th Internati...
# 5      Proceedings of the First IFCIS International C...
# 6      Cooperative Information Systems, 7th Internati...
# 7      Proceedings of the Third International Confere...
# ...                                                  ...
# 50158  Constraint Programming: Basics and Trends, Châ...
# 50198  Next Frontier in Agent-Based Complex Automated...
# 50204  Software Engineering Research, Management and ...
# 50205  Advances in Knowledge Discovery and Management...
# 50210  Philosophy and Theory of Artificial Intelligen...
#
#                                   url  year      ConferenceLocation
# 2      db/conf/coopis/coopis2003.html  2003  Catania, Sicily, Italy
# 4      db/conf/coopis/coopis2001.html  2001           Trento, Italy
# 5        db/conf/coopis/coopis96.html  1996       Brussels, Belgium
# 6      db/conf/coopis/coopis2000.html  2000           Eilat, Israel
# 7        db/conf/coopis/coopis95.html  1995         Vienna, Austria
# ...                               ...   ...                     ...
# 50158   db/journals/lncs/lncs910.html  1995                  France
# 50198       db/series/sci/sci596.html  2015                   Agent
# 50204       db/series/sci/sci578.html  2015       Kitakyushu, Japan
# 50205       db/series/sci/sci471.html  2013           Brest, France
# 50210   db/series/sapere/sapere5.html  2013    Thessaloniki, Greece
#
# [48107 rows x 4 columns]

# %% [markdown]
# ## Filtering the Seminar Related Proceedings

# %%
df_dblp_proceedings = df_dblp_proceedings[df_dblp_proceedings['title'].str.contains("Seminar") == False]
df_dblp_proceedings = df_dblp_proceedings[df_dblp_proceedings['title'].str.contains("seminar") == False]
df_dblp_proceedings
# Out:
#                                                    title  \
# 2      On The Move to Meaningful Internet Systems 200...
# 4      Cooperative Information Systems, 9th Internati...
# 5      Proceedings of the First IFCIS International C...
# 6      Cooperative Information Systems, 7th Internati...
# 7      Proceedings of the Third International Confere...
# ...                                                  ...
# 50158  Constraint Programming: Basics and Trends, Châ...
# 50198  Next Frontier in Agent-Based Complex Automated...
# 50204  Software Engineering Research, Management and ...
# 50205  Advances in Knowledge Discovery and Management...
# 50210  Philosophy and Theory of Artificial Intelligen...
#
#                                   url  year      ConferenceLocation
# 2      db/conf/coopis/coopis2003.html  2003  Catania, Sicily, Italy
# 4      db/conf/coopis/coopis2001.html  2001           Trento, Italy
# 5        db/conf/coopis/coopis96.html  1996       Brussels, Belgium
# 6      db/conf/coopis/coopis2000.html  2000           Eilat, Israel
# 7        db/conf/coopis/coopis95.html  1995         Vienna, Austria
# ...                               ...   ...                     ...
# 50158   db/journals/lncs/lncs910.html  1995                  France
# 50198       db/series/sci/sci596.html  2015                   Agent
# 50204       db/series/sci/sci578.html  2015       Kitakyushu, Japan
# 50205       db/series/sci/sci471.html  2013           Brest, France
# 50210   db/series/sapere/sapere5.html  2013    Thessaloniki, Greece
#
# [48019 rows x 4 columns]

# %% [markdown]
# ## Preparing the Dataframes for the Join Operation

# %% [markdown]
# Before joining the two dataframes, we need to create some auxiliary columns that are going to help us during the following joins operations:

# %%
df_dblp_proceedings['ConferenceNameForJoin'] = df_dblp_proceedings['url'].copy()
df_mag['ConferenceNameForJoin'] = df_mag['ConferenceNormalizedName'].copy()

# %% [markdown]
# Now we're going to "prepare" the conferences name for the join operations:

# %%
df_mag.ConferenceNameForJoin = df_mag.ConferenceNameForJoin.str.split(' ').str[0] + df_mag.ConferenceNameForJoin.str.split(' ').str[1]
df_mag.loc[0:3]
# Out:
#    CitationCount ConferenceLocation ConferenceNormalizedName  \
# 0             12         Austin, TX                disc 2014
# 1             10    Wrocław, Poland                 esa 2014
# 2             20                NaN               enter 2013
# 3              0                NaN                dexa 2002
#
#                          ConferenceSeriesDisplayName  \
# 0   International Symposium on Distributed Computing
# 1                   European Symposium on Algorithms
# 2  Information and Communication Technologies in ...
# 3           Database and Expert Systems Applications
#
#   ConferenceSeriesNormalizedName                           Doi  \
# 0                           DISC  10.1007/978-3-662-45174-8_28
# 1                            ESA  10.1007/978-3-662-44777-2_60
# 2                          ENTER  10.1007/978-3-319-03973-2_13
# 3                           DEXA      10.1007/3-540-46146-9_77
#
#    EstimatedCitation                                      OriginalTitle  \
# 0                 12  The Adaptive Priority Queue with Elimination a...
# 1                 10       Document Retrieval on Repetitive Collections
# 2                 20            SoCoMo Marketing for Travel and Tourism
# 3                  0  Similarity Image Retrieval System Using Hierar...
#
#                                           PaperTitle  Year  \
# 0  the adaptive priority queue with elimination a...  2014
# 1       document retrieval on repetitive collections  2014
# 2            socomo marketing for travel and tourism  2013
# 3  similarity image retrieval system using hierar...  2002
#
#   ConferenceNameForJoin
# 0              disc2014
# 1               esa2014
# 2             enter2013
# 3              dexa2002

# %%
df_dblp_proceedings.ConferenceNameForJoin = df_dblp_proceedings.ConferenceNameForJoin.str.split('/').str[3]
df_dblp_proceedings.ConferenceNameForJoin = df_dblp_proceedings.ConferenceNameForJoin.str.split('.').str[0]

# Operation for the proceedings that have multiple volumes
df_dblp_proceedings.ConferenceNameForJoin = df_dblp_proceedings.ConferenceNameForJoin.str.split('-').str[0]
df_dblp_proceedings = df_dblp_proceedings.drop_duplicates(subset="ConferenceNameForJoin")

# %% [markdown]
# Make sure the indexes are in pair with number of rows

# %%
df_dblp_proceedings = df_dblp_proceedings.reset_index()
df_dblp_proceedings = df_dblp_proceedings.drop(columns=['index'])
df_dblp_proceedings.loc[:3]
# Out:
#                                                title  \
# 0  On The Move to Meaningful Internet Systems 200...
# 1  Cooperative Information Systems, 9th Internati...
# 2  Proceedings of the First IFCIS International C...
# 3  Cooperative Information Systems, 7th Internati...
#
#                               url  year      ConferenceLocation  \
# 0  db/conf/coopis/coopis2003.html  2003  Catania, Sicily, Italy
# 1  db/conf/coopis/coopis2001.html  2001           Trento, Italy
# 2    db/conf/coopis/coopis96.html  1996       Brussels, Belgium
# 3  db/conf/coopis/coopis2000.html  2000           Eilat, Israel
#
#   ConferenceNameForJoin
# 0            coopis2003
# 1            coopis2001
# 2              coopis96
# 3            coopis2000

# %% [markdown]
# ## Join of the New Location Data with the Original Dataframe (Based on the Conference Normalized Name)

# %%
# Merge with the location dataframe
df_mag = pd.merge(df_mag, df_dblp_proceedings, on=['ConferenceNameForJoin'], how='left')

# Combine the two columns
df_mag['ConferenceLocation_x'] = df_mag['ConferenceLocation_x'].fillna(df_mag['ConferenceLocation_y'])
df_mag.rename(columns = {'ConferenceLocation_x':'ConferenceLocation'}, inplace=True)
df_mag = df_mag.drop(columns=['ConferenceLocation_y'])
df_mag = df_mag.drop(columns=['year'])

df_mag.iloc[:4]
# Out:
#    CitationCount  ConferenceLocation ConferenceNormalizedName  \
# 0             12          Austin, TX                disc 2014
# 1             10     Wrocław, Poland                 esa 2014
# 2             20  Innsbruck, Austria               enter 2013
# 3              0    Provence, France                dexa 2002
#
#                          ConferenceSeriesDisplayName  \
# 0   International Symposium on Distributed Computing
# 1                   European Symposium on Algorithms
# 2  Information and Communication Technologies in ...
# 3           Database and Expert Systems Applications
#
#   ConferenceSeriesNormalizedName                           Doi  \
# 0                           DISC  10.1007/978-3-662-45174-8_28
# 1                            ESA  10.1007/978-3-662-44777-2_60
# 2                          ENTER  10.1007/978-3-319-03973-2_13
# 3                           DEXA      10.1007/3-540-46146-9_77
#
#    EstimatedCitation                                      OriginalTitle  \
# 0                 12  The Adaptive Priority Queue with Elimination a...
# 1                 10       Document Retrieval on Repetitive Collections
# 2                 20            SoCoMo Marketing for Travel and Tourism
# 3                  0  Similarity Image Retrieval System Using Hierar...
#
#                                           PaperTitle  Year  \
# 0  the adaptive priority queue with elimination a...  2014
# 1       document retrieval on repetitive collections  2014
# 2            socomo marketing for travel and tourism  2013
# 3  similarity image retrieval system using hierar...  2002
#
#   ConferenceNameForJoin                                              title  \
# 0              disc2014  Distributed Computing - 28th International Sym...
# 1               esa2014  Algorithms - ESA 2014 - 22th Annual European S...
# 2             enter2013  Information and Communication Technologies in ...
# 3              dexa2002  Database and Expert Systems Applications, 13th...
#
#                             url
# 0    db/conf/wdag/disc2014.html
# 1      db/conf/esa/esa2014.html
# 2  db/conf/enter/enter2013.html
# 3    db/conf/dexa/dexa2002.html

# %% [markdown]
# Make sure the indexes are in pair with number of rows

# %%
df_mag = df_mag.reset_index()
df_mag = df_mag.drop(columns=['index'])
df_mag.loc[:2]
# Out:
#    CitationCount  ConferenceLocation ConferenceNormalizedName  \
# 0             12          Austin, TX                disc 2014
# 1             10     Wrocław, Poland                 esa 2014
# 2             20  Innsbruck, Austria               enter 2013
#
#                          ConferenceSeriesDisplayName  \
# 0   International Symposium on Distributed Computing
# 1                   European Symposium on Algorithms
# 2  Information and Communication Technologies in ...
#
#   ConferenceSeriesNormalizedName                           Doi  \
# 0                           DISC  10.1007/978-3-662-45174-8_28
# 1                            ESA  10.1007/978-3-662-44777-2_60
# 2                          ENTER  10.1007/978-3-319-03973-2_13
#
#    EstimatedCitation                                      OriginalTitle  \
# 0                 12  The Adaptive Priority Queue with Elimination a...
# 1                 10       Document Retrieval on Repetitive Collections
# 2                 20            SoCoMo Marketing for Travel and Tourism
#
#                                           PaperTitle  Year  \
# 0  the adaptive priority queue with elimination a...  2014
# 1       document retrieval on repetitive collections  2014
# 2            socomo marketing for travel and tourism  2013
#
#   ConferenceNameForJoin                                              title  \
# 0              disc2014  Distributed Computing - 28th International Sym...
# 1               esa2014  Algorithms - ESA 2014 - 22th Annual European S...
# 2             enter2013  Information and Communication Technologies in ...
#
#                             url
# 0    db/conf/wdag/disc2014.html
# 1      db/conf/esa/esa2014.html
# 2  db/conf/enter/enter2013.html

# %% [markdown]
# Count of how many paper's conference locations are still missing

# %%
n_missing = len(df_mag.index) - len(df_mag.dropna(subset = ['ConferenceLocation']).index)
print(f"{n_missing} missing paper's conference locations")
# Out:
# 1876842 missing paper's conference locations

# %% [markdown]
# Drop of the columns that we don't need

# %%
df_mag = df_mag.drop(columns=['ConferenceNameForJoin', 'title', 'url'])
df_mag.loc[:2]
# Out:
#    CitationCount  ConferenceLocation ConferenceNormalizedName  \
# 0             12          Austin, TX                disc 2014
# 1             10     Wrocław, Poland                 esa 2014
# 2             20  Innsbruck, Austria               enter 2013
#
#                          ConferenceSeriesDisplayName  \
# 0   International Symposium on Distributed Computing
# 1                   European Symposium on Algorithms
# 2  Information and Communication Technologies in ...
#
#   ConferenceSeriesNormalizedName                           Doi  \
# 0                           DISC  10.1007/978-3-662-45174-8_28
# 1                            ESA  10.1007/978-3-662-44777-2_60
# 2                          ENTER  10.1007/978-3-319-03973-2_13
#
#    EstimatedCitation                                      OriginalTitle  \
# 0                 12  The Adaptive Priority Queue with Elimination a...
# 1                 10       Document Retrieval on Repetitive Collections
# 2                 20            SoCoMo Marketing for Travel and Tourism
#
#                                           PaperTitle  Year
# 0  the adaptive priority queue with elimination a...  2014
# 1       document retrieval on repetitive collections  2014
# 2            socomo marketing for travel and tourism  2013

# %% [markdown]
# ## Extraction of the Conference Location Searching Within the Proceeding Title

# %% [markdown]
# Since the match based on the Conference Normalized Name that we created didn't give enough matches, we're going to try a join based on a partial string match over the proceeding title.
#
# **Note**: we don't have the ConferenceInstances "Display Names", but only the ConferenceSeriesDisplayName. For this reason, we're going to use also the Conference Year for matching only the specific row that we need.

# %% [markdown]
# Let's get the conferences that need to be fixed:

# %%
df_mag_conferences = df_mag[["ConferenceNormalizedName", "ConferenceSeriesDisplayName", "ConferenceLocation", "Year"]]

# %% [markdown]
# Drop of the papers that don't need their location to be fixed.

# %%
df_mag_conferences = df_mag_conferences[df_mag_conferences["ConferenceLocation"].isna()]
df_mag_conferences
# Out:
#         ConferenceNormalizedName  \
# 10                      acc 1990
# 13                 asilomar 1991
# 23                      ire 1964
# 26                     icet 2007
# 27                     ecml 1994
# ...                          ...
# 4409793              icieam 2017
# 4409796                dueu 2018
# 4409803                  ra 2004
# 4409806               fnces 2012
# 4409809                 acc 1988
#
#                                ConferenceSeriesDisplayName ConferenceLocation  \
# 10                             American Control Conference                NaN
# 13       Asilomar Conference on Signals, Systems and Co...                NaN
# 23                     IRE International Convention Record                NaN
# 26       International Conference on Emerging Technologies                NaN
# 27                 European conference on Machine Learning                NaN
# ...                                                    ...                ...
# 4409793  International Conference on Industrial Enginee...                NaN
# 4409796  International Conference of Design, User Exper...                NaN
# 4409803                          Robotics and Applications                NaN
# 4409806       National Conference for Engineering Sciences                NaN
# 4409809                        American Control Conference                NaN
#
#          Year
# 10       1990
# 13       1991
# 23       1964
# 26       2007
# 27       1994
# ...       ...
# 4409793  2017
# 4409796  2018
# 4409803  2004
# 4409806  2012
# 4409809  1988
#
# [1876842 rows x 4 columns]

# %% [markdown]
# Drop of the duplicated conferences. We only need unique values.

# %%
df_mag_conferences = df_mag_conferences.drop_duplicates(subset="ConferenceNormalizedName")

n_conf = df_mag_conferences.__len__()
print(f"Now we only need to search for the location of {n_conf} unique conferences")
# Out:
# Now we only need to search for the location of 17027 unique conferences

# %% [markdown]
# Make sure the indexes are in pair with number of rows

# %%
df_mag_conferences = df_mag_conferences.reset_index()
df_mag_conferences
# Out:
#          index ConferenceNormalizedName  \
# 0           10                 acc 1990
# 1           13            asilomar 1991
# 2           23                 ire 1964
# 3           26                icet 2007
# 4           27                ecml 1994
# ...        ...                      ...
# 17022  4391498                qels 1990
# 17023  4392151                iait 2014
# 17024  4395100                  gi 1998
# 17025  4405987               iwaal 2016
# 17026  4409381            escience 2015
#
#                              ConferenceSeriesDisplayName ConferenceLocation  \
# 0                            American Control Conference                NaN
# 1      Asilomar Conference on Signals, Systems and Co...                NaN
# 2                    IRE International Convention Record                NaN
# 3      International Conference on Emerging Technologies                NaN
# 4                European conference on Machine Learning                NaN
# ...                                                  ...                ...
# 17022   Quantum Electronics and Laser Science Conference                NaN
# 17023                 Advances in Information Technology                NaN
# 17024                                 Graphics Interface                NaN
# 17025  International Workshop on Ambient Assisted Living                NaN
# 17026          IEEE International Conference on eScience                NaN
#
#        Year
# 0      1990
# 1      1991
# 2      1964
# 3      2007
# 4      1994
# ...     ...
# 17022  1990
# 17023  2014
# 17024  1998
# 17025  2016
# Searching the location for the conference 643 out of 17027
# Searching the location for the conference 644 out of 17027
# Searching the location for the conference 645 out of 17027
# Searching the location for the conference 646 out of 17027
# Searching the location for the conference 647 out of 17027
# Searching the location for the conference 648 out of 17027
# Searching the location for the conference 649 out of 17027
# Searching the location for the conference 650 out of 17027
# Searching the location for the conference 651 out of 17027
# Searching the location for the conference 652 out of 17027
# Searching the location for the conference 653 out of 17027
# Searching the location for the conference 654 out of 17027
# Searching the location for the conference 655 out of 17027
# Searching the location for the conference 656 out of 17027
# Searching the location for the conference 657 out of 17027
# Searching the location for the conference 658 out of 17027
# Searching the location for the conference 659 out of 17027
# Searching the location for the conference 660 out of 17027
# Searching the location for the conference 661 out of 17027
# Searching the location for the conference 662 out of 17027
# Searching the location for the conference 663 out of 17027
# Searching the location for the conference 664 out of 17027
# Searching the location for the conference 665 out of 17027
# Searching the location for the conference 666 out of 17027
# Searching the location for the conference 667 out of 17027
# Searching the location for the conference 668 out of 17027
# Searching the location for the conference 669 out of 17027
# Searching the location for the conference 670 out of 17027
# Searching the location for the conference 671 out of 17027
# Searching the location for the conference 672 out of 17027
# Searching the location for the conference 673 out of 17027
# Searching the location for the conference 674 out of 17027
# Searching the location for the conference 675 out of 17027

# %% [markdown]
# Count of how many conferences locations are still missing:

# %%
n_missing = len(df_mag_conferences.index) - len(df_mag_conferences.dropna(subset = ['ConferenceLocation']).index)
print(f"{n_missing} missing paper's conference locations")

# %% [markdown]
# Drop of the conferences that still don't have a location:

# %%
df_mag_conferences = df_mag_conferences.dropna(subset = ['ConferenceLocation'])

# %% [markdown]
# Drop of the columns that we don't need anymore

# %%
df_mag_conferences = df_mag_conferences.drop(columns=['index', 'ConferenceSeriesDisplayName', 'Year'])

# %%
# TODO DEBUG
df_mag_conferences.to_csv(path_file_export + 'out_mag_conf_fixed_tmp.csv')

# %% [markdown]
# ## Join of the New Location Data with the Original Dataframe (Based on the Proceeding Title and Year)

# %% [markdown]
# Join with the original dataframe

# %%
df_mag = pd.merge(df_mag, df_mag_conferences, on=['ConferenceNormalizedName'], how='left')

# Combine the two columns
df_mag['ConferenceLocation_x'] = df_mag['ConferenceLocation_x'].fillna(df_mag['ConferenceLocation_y'])
df_mag.rename(columns = {'ConferenceLocation_x':'ConferenceLocation'}, inplace=True)
df_mag = df_mag.drop(columns=['ConferenceLocation_y'])

df_mag.iloc[:5]

# %% [markdown]
# Count of how many paper's conference locations are still missing

# %%
n_missing = len(df_mag.index) - len(df_mag.dropna(subset = ['ConferenceLocation']).index)
print(f"{n_missing} missing paper's conference locations")

# %% [markdown]
# ## Write of the Final CSV on Disk

# %% [markdown]
# Saving the resulting dataframe on disk in CSV format.

# %%
# Write of the resulting CSV on Disk
df_mag.to_csv(path_file_export + 'out_mag_citations_and_locations.csv')
print(f'Successfully Exported the Preprocessed CSV to {path_file_export}out_mag_citations_and_locations.csv')

# %% [markdown]
# Check of the Exported CSV to be sure that everything went fine.

# %%
# Check of the Exported CSV
df_mag_exported_csv = pd.read_csv(path_file_export + 'out_mag_citations_and_locations.csv', low_memory=False, index_col=[0])
df_mag_exported_csv
