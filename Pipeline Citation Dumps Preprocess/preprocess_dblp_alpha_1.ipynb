# %% [markdown]
# # Preprocess DBLP) Dataset
#
# Jupyter Notebook for the preprocessing of the DBLP dump.
#
# ## TODO TODO TODO
#
# For this process, the following CSV files are needed: ```ConferenceInstances.txt```, ```ConferenceSeries.txt```, ```Papers.txt```.
# The above files can be found here: https://archive.org/download/mag-2021-06-07/mag/
#
# In particular, the following operations are going to be executed:
# * Opening of ConferenceInstances and ConferenceSeries CSVs
# * Drop of the useless columns
# * Chuncked Processing of the Papers CSV
#     * Drop of the useless columns
#     * Drop of papers without DOI
#     * Drop of papers from journals and books rows
# * Merge with the processed conferences data
#
# Lastly, the entire preprocessed dump is going to be saved on disk in CSV format

# %%
# Libraries Import
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## File Paths
# Please set your working directory paths.

# %%
# ******************* PATHS ********************+

# Dumps Directory Path
path_file_import = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Import/'

# CSV Exports Directory Path
path_file_export = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/'

# %% [markdown]
# ## Dump Conversion from XML to CSV
# ### About the Conversion Script that is Going to Be Used
# For this initial part of the work, we're going to use a conversion script specifically made for this purpose by *Thom Hurks*. All the rights of that script goes to him.
#
# For semplicity, **a copy of the script has already been included in the present folder**.
# You can read more about how the script works and other command line options on its original [Github Repository](https://github.com/ThomHurks/dblp-to-csv).
#
# ### What is Needed
# Before proceeding, you first need to download and unpack the DBLP XML file from [here](https://dblp.org/xml/release/). You also need to download the latest DTD file that you can find in the same page.
#
# ### Running the Conversion Script
# To run the conversion script, you first need to place the XML and DTD files in the same folder of the script.
# Then, you can run the following shell commands: <br>
# ```chmod +x XMLToCSV.py ```<br>
# ```./XMLToCSV.py dblp.xml dblp.dtd out_dblp_raw.csv```<br><br>
# **NOTE**: Be sure to properly specify the XML and DTD file names
#
# ### Deleting Unnecessary Output Files
# The script generates an output file for each element in the XML file (such as articles, books, etc). We only need the CSV file about **inproceedings**. In this example, its name is going to be *out_dblp_raw_inproceedings.csv*.
#
# If you named the output files differently, you can specify your file name in the following cell.

# %%
csv_inproceedings_name = 'out_dblp_raw_inproceedings.csv'

# %% [markdown]
# **NOTE**: Please copy the inproceedings file in the Import directory specified above

# %% [markdown]
# ## Preprocess of the DBLP Dump
# In this phase we're going to use the CSV file generated from the previous conversion phase.

# %%
# Read of the DBLP Raw Dump

df_dblp = pd.read_csv(path_file_import + csv_inproceedings_name, sep=';', low_memory=False)
df_dblp
# Out:
#               id                                             author  \
# 0        3062806                                    Arnon Rosenthal
# 1        3062808                         Qiming Chen|Umeshwar Dayal
# 2        3062809  Emmanuel Cecchet|Renaud Lachaize|Takoua Abdell...
# 3        3062810        Robert Grob|Stefanie Kethers|Stephan Jacobs
# 4        3062811  Evaggelia Pitoura|George Samaras|Panos K. Chry...
# ...          ...                                                ...
# 2990257  8958667                               Tarek Richard Besold
# 2990258  8958671                                     Pierre Steiner
# 2990259  8958672                                   Stuart Armstrong
# 2990260  8958682                                          Sam Freed
# 2990261  8958686                                     Peter Bokulich
#
#         author-aux         author-orcid              booktitle cdrom  \
# 0              NaN                  NaN                   SWEE   NaN
# 1              NaN                  NaN                 CoopIS   NaN
# 2              NaN                  NaN  CoopIS/DOA/ODBASE (2)   NaN
# 3              NaN                  NaN                 CoopIS   NaN
# 4              NaN                  NaN                 CoopIS   NaN
# ...            ...                  ...                    ...   ...
# 2990257        NaN  0000-0002-8002-0049                  PT-AI   NaN
# 2990258        NaN                  NaN                  PT-AI   NaN
# 2990259        NaN                  NaN                  PT-AI   NaN
# 2990260        NaN                  NaN                  PT-AI   NaN
# 2990261        NaN                  NaN                  PT-AI   NaN
#
#                                                       cite cite-label  \
# 0                                                      NaN        NaN
# 1        ...|...|...|books/mk/GrayR93|books/mk/elmagarm...        NaN
# 2                                                      NaN        NaN
# 3                                                      NaN        NaN
# 4        ...|...|...|...|...|...|...|...|...|...|...|.....        NaN
# ...                                                    ...        ...
# 2990257                                                NaN        NaN
# 2990258                                                NaN        NaN
# 2990259                                                NaN        NaN
# 2990260                                                NaN        NaN
# 2990261                                                NaN        NaN
#
#                      crossref editor editor-orcid  \
# 0              conf/swee/1998    NaN          NaN
# 1            conf/coopis/2000    NaN          NaN
# 2          conf/coopis/2004-2    NaN          NaN
# 3            conf/coopis/1994    NaN          NaN
# 4            conf/coopis/2000    NaN          NaN
# ...                       ...    ...          ...
# 2990257  series/sapere/2013-5    NaN          NaN
# 2990258  series/sapere/2013-5    NaN          NaN
# 2990259  series/sapere/2013-5    NaN          NaN
# 2990260  series/sapere/2013-5    NaN          NaN
# 2990261  series/sapere/2013-5    NaN          NaN
#
#                                                        ee ee-type    i  \
# 0        http://www.mitre.org/support/swee/rosenthal.html     NaN  NaN
# 1                     https://doi.org/10.1007/10722620_29     NaN  NaN
# 2            https://doi.org/10.1007/978-3-540-30469-2_46     NaN  NaN
# 3                                                     NaN     NaN  NaN
# 4                      https://doi.org/10.1007/10722620_9     NaN  NaN
# ...                                                   ...     ...  ...
# 2990257       https://doi.org/10.1007/978-3-642-31674-6_9     NaN  NaN
# 2990258      https://doi.org/10.1007/978-3-642-31674-6_20     NaN  NaN
# 2990259      https://doi.org/10.1007/978-3-642-31674-6_25     NaN  NaN
# 2990260      https://doi.org/10.1007/978-3-642-31674-6_12     NaN  NaN
# 2990261       https://doi.org/10.1007/978-3-642-31674-6_3     NaN  NaN
#
#                                   key       mdate month note note-type number  \
# 0                www/org/mitre/future  2019-07-30   NaN  NaN       NaN    NaN
# 1                 conf/coopis/ChenD00  2017-05-24   NaN  NaN       NaN    NaN
# 2          conf/coopis/AbdellatifCL04  2017-05-25   NaN  NaN       NaN    NaN
# 3                conf/coopis/GrobJK94  2019-08-08   NaN  NaN       NaN    NaN
# 4        conf/coopis/PapastavrouCSP00  2017-05-24   NaN  NaN       NaN    NaN
# ...                               ...         ...   ...  ...       ...    ...
# 2990257        series/sapere/Besold13  2019-09-06   NaN  NaN       NaN    NaN
# 2990258       series/sapere/Steiner13  2019-09-06   NaN  NaN       NaN    NaN
# 2990259     series/sapere/Armstrong13  2019-09-06   NaN  NaN       NaN    NaN
# 2990260         series/sapere/Freed13  2019-09-06   NaN  NaN       NaN    NaN
# 2990261      series/sapere/Bokulich13  2019-09-06   NaN  NaN       NaN    NaN
#
#              pages publtype  sub  sup  \
# 0              NaN      NaN  NaN  NaN
# 1          311-322      NaN  NaN  NaN
# 2        1571-1589      NaN  NaN  NaN
# 3          134-145      NaN  NaN  NaN
# 4          102-113      NaN  NaN  NaN
# ...            ...      ...  ...  ...
# 2990257    121-132      NaN  NaN  NaN
# 2990258    265-276      NaN  NaN  NaN
# 2990259    335-347      NaN  NaN  NaN
# 2990260    167-177      NaN  NaN  NaN
# 2990261      29-41      NaN  NaN  NaN
#
#                                                      title title-bibtex   tt  \
# 0        The Future of Classic Data Administration: Obj...          NaN  NaN
# 1        Multi-Agent Cooperative Transactions for E-Com...          NaN  NaN
# 2        Evaluation of a Group Communication Middleware...          NaN  NaN
# 3        Towards CIS in Quality Management - Integratio...          NaN  NaN
# 4        An Evaluation of the Java-Based Approaches to ...          NaN  NaN
# ...                                                    ...          ...  ...
# 2990257  Turing Revisited: A Cognitively-Inspired Decom...          NaN  NaN
# 2990258  C.S. Peirce and Artificial Intelligence: Histo...          NaN  NaN
# 2990259     Risks and Mitigation Strategies for Oracle AI.          NaN  NaN
# 2990260     Practical Introspection as Inspiration for AI.          NaN  NaN
# 2990261  The Physics and Metaphysics of Computation and...          NaN  NaN
#
#                                                      url  volume  year
# 0                             db/conf/swee/swee1998.html     NaN  1998
# 1                 db/conf/coopis/coopis2000.html#ChenD00     NaN  2000
# 2        db/conf/coopis/coopis2004-2.html#AbdellatifCL04     NaN  2004
# 3                  db/conf/coopis/coopis94.html#GrobJK94     NaN  1994
# 4        db/conf/coopis/coopis2000.html#PapastavrouCSP00     NaN  2000
# ...                                                  ...     ...   ...
# 2990257           db/series/sapere/sapere5.html#Besold13     NaN  2011
# 2990258          db/series/sapere/sapere5.html#Steiner13     NaN  2011
# 2990259        db/series/sapere/sapere5.html#Armstrong13     NaN  2011
# 2990260            db/series/sapere/sapere5.html#Freed13     NaN  2011
# 2990261         db/series/sapere/sapere5.html#Bokulich13     NaN  2011
#
# [2990262 rows x 30 columns]

# %% [markdown]
# Here the useless columns are going to be removed from the dataframe.

# %%
df_dblp = df_dblp.drop(columns=['author', 'author-aux', 'author-orcid', 'booktitle', 'cdrom', 'cite', 'cite-label', 'editor', 'editor-orcid', 'ee-type', 'i', 'mdate', 'month', 'note', 'note-type', 'number', 'pages', 'publtype', 'sub', 'sup', 'title', 'title-bibtex', 'tt', 'volume'])
df_dblp
# Out:
#               id              crossref  \
# 0        3062806        conf/swee/1998
# 1        3062808      conf/coopis/2000
# 2        3062809    conf/coopis/2004-2
# 3        3062810      conf/coopis/1994
# 4        3062811      conf/coopis/2000
# ...          ...                   ...
# 2990257  8958667  series/sapere/2013-5
# 2990258  8958671  series/sapere/2013-5
# 2990259  8958672  series/sapere/2013-5
# 2990260  8958682  series/sapere/2013-5
# 2990261  8958686  series/sapere/2013-5
#
#                                                        ee  \
# 0        http://www.mitre.org/support/swee/rosenthal.html
# 1                     https://doi.org/10.1007/10722620_29
# 2            https://doi.org/10.1007/978-3-540-30469-2_46
# 3                                                     NaN
# 4                      https://doi.org/10.1007/10722620_9
# ...                                                   ...
# 2990257       https://doi.org/10.1007/978-3-642-31674-6_9
# 2990258      https://doi.org/10.1007/978-3-642-31674-6_20
# 2990259      https://doi.org/10.1007/978-3-642-31674-6_25
# 2990260      https://doi.org/10.1007/978-3-642-31674-6_12
# 2990261       https://doi.org/10.1007/978-3-642-31674-6_3
#
#                                   key  \
# 0                www/org/mitre/future
# 1                 conf/coopis/ChenD00
# 2          conf/coopis/AbdellatifCL04
# 3                conf/coopis/GrobJK94
# 4        conf/coopis/PapastavrouCSP00
# ...                               ...
# 2990257        series/sapere/Besold13
# 2990258       series/sapere/Steiner13
# 2990259     series/sapere/Armstrong13
# 2990260         series/sapere/Freed13
# 2990261      series/sapere/Bokulich13
#
#                                                      url  year
# 0                             db/conf/swee/swee1998.html  1998
# 1                 db/conf/coopis/coopis2000.html#ChenD00  2000
# 2        db/conf/coopis/coopis2004-2.html#AbdellatifCL04  2004
# 3                  db/conf/coopis/coopis94.html#GrobJK94  1994
# 4        db/conf/coopis/coopis2000.html#PapastavrouCSP00  2000
# ...                                                  ...   ...
# 2990257           db/series/sapere/sapere5.html#Besold13  2011
# 2990258          db/series/sapere/sapere5.html#Steiner13  2011
# 2990259        db/series/sapere/sapere5.html#Armstrong13  2011
# 2990260            db/series/sapere/sapere5.html#Freed13  2011
# 2990261         db/series/sapere/sapere5.html#Bokulich13  2011
#
# [2990262 rows x 6 columns]

# %% [markdown]
# Filtering of the papers without a DOI

# %%
df_dblp = df_dblp.loc[df_dblp.ee.str.contains("https://doi.org/", na=False)]
df_dblp
# Out:
#               id              crossref  \
# 1        3062808      conf/coopis/2000
# 2        3062809    conf/coopis/2004-2
# 4        3062811      conf/coopis/2000
# 5        3062812        conf/coopis/97
# 6        3062813      conf/coopis/2003
# ...          ...                   ...
# 2990257  8958667  series/sapere/2013-5
# 2990258  8958671  series/sapere/2013-5
# 2990259  8958672  series/sapere/2013-5
# 2990260  8958682  series/sapere/2013-5
# 2990261  8958686  series/sapere/2013-5
#
#                                                         ee  \
# 1                      https://doi.org/10.1007/10722620_29
# 2             https://doi.org/10.1007/978-3-540-30469-2_46
# 4                       https://doi.org/10.1007/10722620_9
# 5        http://doi.ieeecomputersociety.org/10.1109/COO...
# 6             https://doi.org/10.1007/978-3-540-39964-3_50
# ...                                                    ...
# 2990257        https://doi.org/10.1007/978-3-642-31674-6_9
# 2990258       https://doi.org/10.1007/978-3-642-31674-6_20
# 2990259       https://doi.org/10.1007/978-3-642-31674-6_25
# 2990260       https://doi.org/10.1007/978-3-642-31674-6_12
# 2990261        https://doi.org/10.1007/978-3-642-31674-6_3
#
#                                      key  \
# 1                    conf/coopis/ChenD00
# 2             conf/coopis/AbdellatifCL04
# 4           conf/coopis/PapastavrouCSP00
# 5        conf/coopis/BultzingsloewenKK97
# 6              conf/coopis/GiacolettoA03
# ...                                  ...
# 2990257           series/sapere/Besold13
# 2990258          series/sapere/Steiner13
# 2990259        series/sapere/Armstrong13
# 2990260            series/sapere/Freed13
# 2990261         series/sapere/Bokulich13
#
#                                                       url  year
# 1                  db/conf/coopis/coopis2000.html#ChenD00  2000
# 2         db/conf/coopis/coopis2004-2.html#AbdellatifCL04  2004
# 4         db/conf/coopis/coopis2000.html#PapastavrouCSP00  2000
# 5        db/conf/coopis/coopis97.html#BultzingsloewenKK97  1997
# 6            db/conf/coopis/coopis2003.html#GiacolettoA03  2003
# ...                                                   ...   ...
# 2990257            db/series/sapere/sapere5.html#Besold13  2011
# 2990258           db/series/sapere/sapere5.html#Steiner13  2011
# 2990259         db/series/sapere/sapere5.html#Armstrong13  2011
# 2990260             db/series/sapere/sapere5.html#Freed13  2011
# 2990261          db/series/sapere/sapere5.html#Bokulich13  2011
#
# [2481952 rows x 6 columns]

# %% [markdown]
# Saving the resulting dataframe on disk in CSV format.

# %%
# Write of the resulting CSV on Disk
df_dblp.to_csv(path_file_export + 'out_dblp.csv')

# %% [markdown]
# Check of the Exported CSV to be sure that everything went fine.

# %%
# Check of the Exported CSV
df_dblp_exported_csv = pd.read_csv(path_file_export + 'out_dblp.csv', low_memory=False)
df_dblp_exported_csv
# Out:
#          Unnamed: 0       id              crossref  \
# 0                 1  3062808      conf/coopis/2000
# 1                 2  3062809    conf/coopis/2004-2
# 2                 4  3062811      conf/coopis/2000
# 3                 5  3062812        conf/coopis/97
# 4                 6  3062813      conf/coopis/2003
# ...             ...      ...                   ...
# 2481947     2990257  8958667  series/sapere/2013-5
# 2481948     2990258  8958671  series/sapere/2013-5
# 2481949     2990259  8958672  series/sapere/2013-5
# 2481950     2990260  8958682  series/sapere/2013-5
# 2481951     2990261  8958686  series/sapere/2013-5
#
#                                                         ee  \
# 0                      https://doi.org/10.1007/10722620_29
# 1             https://doi.org/10.1007/978-3-540-30469-2_46
# 2                       https://doi.org/10.1007/10722620_9
# 3        http://doi.ieeecomputersociety.org/10.1109/COO...
# 4             https://doi.org/10.1007/978-3-540-39964-3_50
# ...                                                    ...
# 2481947        https://doi.org/10.1007/978-3-642-31674-6_9
# 2481948       https://doi.org/10.1007/978-3-642-31674-6_20
# 2481949       https://doi.org/10.1007/978-3-642-31674-6_25
# 2481950       https://doi.org/10.1007/978-3-642-31674-6_12
# 2481951        https://doi.org/10.1007/978-3-642-31674-6_3
#
#                                      key  \
# 0                    conf/coopis/ChenD00
# 1             conf/coopis/AbdellatifCL04
# 2           conf/coopis/PapastavrouCSP00
# 3        conf/coopis/BultzingsloewenKK97
# 4              conf/coopis/GiacolettoA03
# ...                                  ...
# 2481947           series/sapere/Besold13
# 2481948          series/sapere/Steiner13
# 2481949        series/sapere/Armstrong13
# 2481950            series/sapere/Freed13
# 2481951         series/sapere/Bokulich13
#
#                                                       url  year
# 0                  db/conf/coopis/coopis2000.html#ChenD00  2000
# 1         db/conf/coopis/coopis2004-2.html#AbdellatifCL04  2004
# 2         db/conf/coopis/coopis2000.html#PapastavrouCSP00  2000
# 3        db/conf/coopis/coopis97.html#BultzingsloewenKK97  1997
# 4            db/conf/coopis/coopis2003.html#GiacolettoA03  2003
# ...                                                   ...   ...
# 2481947            db/series/sapere/sapere5.html#Besold13  2011
# 2481948           db/series/sapere/sapere5.html#Steiner13  2011
# 2481949         db/series/sapere/sapere5.html#Armstrong13  2011
# 2481950             db/series/sapere/sapere5.html#Freed13  2011
# 2481951          db/series/sapere/sapere5.html#Bokulich13  2011
#
# [2481952 rows x 7 columns]

# %% [markdown]
# ## Preprocess of Papers CSV
# The Papers CSV is going to be processed in chunks, due to its size.
#
# The following operations are going to be executed:
# * Drop of the useless columns
# * Filtering of papers without DOI
# * Filtering papers that are not related to conferences
# * Drop of the doctype column
# * Write of the processed file on disk (in CSV format)

# %%
# ******************* PAPERS ********************

# Read of previously prerocessed CSV
df_mag_papers = None
if read_preprocessed_papers:
    df_mag_papers = pd.read_csv(preprocessed_papers_csv_path, low_memory=False, index_col=0)
else:
    # The Papers CSV is going to be processed in chunks, due to its size

    # The column names follow the MAG' scheme official documentation
    df_mag_papers_col_names = ['PaperID', 'Rank', 'Doi', 'DocType', 'PaperTitle', 'OriginalTitle', 'BookTitle', 'Year', 'Date', 'OnlineDate', 'Publisher', 'JournalID', 'ConferenceSeriesID', 'ConferenceInstanceID', 'Volume', 'Issue', 'FirstPage', 'LastPage', 'ReferenceCount', 'CitationCount', 'EstimatedCitation', 'OriginalVenue', 'FamilyID', 'FamilyRank', 'Retracion', 'CreatedDate']

    # List of processed chunks.
    df_mag_papers_list_of_chunks = list()

    # Define of the chunk size
    chunksize = 10 ** 7

    count = 1
    with pd.read_csv(path_file_import + 'Papers.txt', sep='\t', chunksize=chunksize, low_memory=False, on_bad_lines='skip', names=df_mag_papers_col_names) as reader:
        for chunk in reader:

            # Drop of the useless columns
            chunk = chunk.drop(columns=['Rank', 'OnlineDate', 'Publisher', 'Volume', 'Issue', 'FirstPage', 'LastPage', 'ReferenceCount', 'OriginalVenue', 'FamilyID', 'FamilyRank', 'Retracion', 'CreatedDate', 'JournalID', 'BookTitle', 'Date'])

            # Filtering of papers without DOI
            chunk = chunk.dropna(subset = ['Doi'])

            # Filtering papers that are not related to conferences
            chunk = chunk[chunk.DocType == 'Conference']

            # Drop of the doctype column
            chunk = chunk.drop(columns=['DocType'])

            # Insert of the resulting chunk in the list 
            df_mag_papers_list_of_chunks.append(chunk)

            print(f'Successfully processed chunk {count} out of around {260000000 / chunksize}')
            count += 1
            break

    # Concatenation of the processed chunks
    df_mag_papers = pd.concat(df_mag_papers_list_of_chunks)

    # Empty the list to free some memory
    df_mag_papers_list_of_chunks = list()

    # Write of the resulting CSV on Disk
    df_mag_papers.to_csv(path_file_export + 'out_mag_papers.csv')

df_mag_papers

# %% [markdown]
# ## Merge of Conferences and Papers Data

# %%
# ******************* MERGE OF CONFERENCES AND PAPERS DATA ********************

# Merge of conferences and papers data over the conferenceseries id columnn to get the conference series name
# The papers' row that will not match will be preserved
df_mag_preprocessed = pd.merge(df_mag_papers, df_mag_conf_series, on=['ConferenceSeriesID'], how='left')

# Merge of conferences and papers data over the conferenceinstances id columnn
# The papers' row that will not match will be preserved
df_mag_preprocessed = pd.merge(df_mag_preprocessed, df_mag_conf_instances, on=['ConferenceInstanceID'], how='left')

# Drop of the duplicated columns
df_mag_preprocessed = df_mag_preprocessed.drop(columns=['ConferenceSeriesID_y'])
df_mag_preprocessed.rename(columns = {'ConferenceSeriesID_x':'ConferenceSeriesID'}, inplace=True)

# Removing broken data (four records seems to have mismatched types in some columns)
df_mag_preprocessed = df_mag_preprocessed.dropna(subset = ['CitationCount'])

# Write of the resulting CSV on Disk
df_mag_preprocessed.to_csv(path_file_export + 'out_mag_citations_count_and_conferences.csv')

df_mag_preprocessed

# %% [markdown]
# Check of the Exported CSV to be sure that everything went fine.

# %%
# Check of the Exported CSV
df_mag_exported_csv = pd.read_csv(path_file_export + 'out_mag_citations_count_and_conferences.csv', low_memory=False)
df_mag_exported_csv

# %% [markdown]
# Order by citations count descending to see the articles with the most citations

# %%
# Order by citations count descending to see the articles with the most citations
df_mag_exported_csv = df_mag_exported_csv.sort_values(by='CitationCount', ascending=False)
df_mag_exported_csv
