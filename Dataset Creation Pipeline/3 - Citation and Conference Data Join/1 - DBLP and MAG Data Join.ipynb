# %% [markdown]
# # Citation and Conference Data Join - DBLP and MAG
#
# Jupyter Notebook for the join of the conferences and location data between the DBLP and MAG dumps.
#
# For this process, the following CSV files are needed: ```out_dblp_papers_and_locations_final.csv``` and ```out_mag_citations_and_locations_final.csv```. <br>
# The above files must be generated running the Notebooks that are contained in the ```2 - Conference Location Fix``` folder of this Project.
#
# In particular, the following operations are going to be executed:
# * Opening of the CSV preprocessed dumps
# * Creation of the conference identifiers for DBLP
# * Join between the two datasets
# * Drop of the useless columns
# * Fix of the mismatched data types
#
# Lastly, the entire preprocessed dump is going to be saved on disk in CSV format

# %%
# Libraries Import
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## File Paths
# Please set your working directory paths.

# %%
# ******************* PATHS ********************+

# Dumps Directory Path
path_file_import = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Import/'

# CSV Exports Directory Path
path_file_export = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/'

# %% [markdown]
# ## Read of the CSV Preprocessed Dumps

# %%
df_dblp = pd.read_csv(path_file_export + 'out_dblp_papers_and_locations_final.csv', low_memory=False, index_col=[0])
df_dblp
# Out:
#                          ConferenceLocation  \
# 0                             Eilat, Israel
# 1                         Agia Napa, Cyprus
# 2                             Eilat, Israel
# 3        Kiawah Island, South Carolina, USA
# 4                    Catania, Sicily, Italy
# ...                                     ...
# 2434139                Thessaloniki, Greece
# 2434140                Thessaloniki, Greece
# 2434141                Thessaloniki, Greece
# 2434142                Thessaloniki, Greece
# 2434143                Thessaloniki, Greece
#
#                                            ConferenceTitle  \
# 0        Cooperative Information Systems, 7th Internati...
# 1        On the Move to Meaningful Internet Systems 200...
# 2        Cooperative Information Systems, 7th Internati...
# 3        Proceedings of the Second IFCIS International ...
# 4        On The Move to Meaningful Internet Systems 200...
# ...                                                    ...
# 2434139  Philosophy and Theory of Artificial Intelligen...
# 2434140  Philosophy and Theory of Artificial Intelligen...
# 2434141  Philosophy and Theory of Artificial Intelligen...
# 2434142  Philosophy and Theory of Artificial Intelligen...
# 2434143  Philosophy and Theory of Artificial Intelligen...
#
#                      crossref  \
# 0            conf/coopis/2000
# 1          conf/coopis/2004-2
# 2            conf/coopis/2000
# 3              conf/coopis/97
# 4            conf/coopis/2003
# ...                       ...
# 2434139  series/sapere/2013-5
# 2434140  series/sapere/2013-5
# 2434141  series/sapere/2013-5
# 2434142  series/sapere/2013-5
# 2434143  series/sapere/2013-5
#
#                                                         ee  \
# 0                      https://doi.org/10.1007/10722620_29
# 1             https://doi.org/10.1007/978-3-540-30469-2_46
# 2                       https://doi.org/10.1007/10722620_9
# 3        http://doi.ieeecomputersociety.org/10.1109/COO...
# 4             https://doi.org/10.1007/978-3-540-39964-3_50
# ...                                                    ...
# 2434139        https://doi.org/10.1007/978-3-642-31674-6_9
# 2434140       https://doi.org/10.1007/978-3-642-31674-6_20
# 2434141       https://doi.org/10.1007/978-3-642-31674-6_25
# 2434142       https://doi.org/10.1007/978-3-642-31674-6_12
# 2434143        https://doi.org/10.1007/978-3-642-31674-6_3
#
#                                      key                               url  \
# 0                    conf/coopis/ChenD00    db/conf/coopis/coopis2000.html
# 1             conf/coopis/AbdellatifCL04  db/conf/coopis/coopis2004-2.html
# 2           conf/coopis/PapastavrouCSP00    db/conf/coopis/coopis2000.html
# 3        conf/coopis/BultzingsloewenKK97      db/conf/coopis/coopis97.html
# 4              conf/coopis/GiacolettoA03    db/conf/coopis/coopis2003.html
# ...                                  ...                               ...
# 2434139           series/sapere/Besold13     db/series/sapere/sapere5.html
# 2434140          series/sapere/Steiner13     db/series/sapere/sapere5.html
# 2434141        series/sapere/Armstrong13     db/series/sapere/sapere5.html
# 2434142            series/sapere/Freed13     db/series/sapere/sapere5.html
# 2434143         series/sapere/Bokulich13     db/series/sapere/sapere5.html
#
#          year
# 0        2000
# 1        2004
# 2        2000
# 3        1997
# 4        2003
# ...       ...
# 2434139  2011
# 2434140  2011
# 2434141  2011
# 2434142  2011
# 2434143  2011
#
# [2434144 rows x 7 columns]

# %%
df_mag = pd.read_csv(path_file_export + 'out_mag_citations_and_locations_final.csv', low_memory=False, index_col=[0])
df_mag.drop(df_mag.filter(regex="Unname"), axis=1, inplace=True)
df_mag
# Out:
#          CitationCount        ConferenceLocation ConferenceNormalizedName  \
# 0                   12                Austin, TX                disc 2014
# 1                   10           Wrocław, Poland                 esa 2014
# 2                   20        Innsbruck, Austria               enter 2013
# 3                    0          Provence, France                dexa 2002
# 4                   19          Zakopane, Poland              icaisc 2006
# ...                ...                       ...                      ...
# 4409807              0                 Singapore               iecon 2020
# 4409808              0             Paris, France                bmsb 2020
# 4409809              0                       NaN                 acc 1988
# 4409810              0     Orlando, Florida, USA              icassp 2002
# 4409811              0  Smart City, Xi'an, China                icit 2020
#
#                                ConferenceSeriesDisplayName  \
# 0         International Symposium on Distributed Computing
# 1                         European Symposium on Algorithms
# 2        Information and Communication Technologies in ...
# 3                 Database and Expert Systems Applications
# 4        International Conference on Artificial Intelli...
# ...                                                    ...
# 4409807   Conference of the Industrial Electronics Society
# 4409808  International Symposium on Broadband Multimedi...
# 4409809                        American Control Conference
# 4409810  International Conference on Acoustics, Speech,...
# 4409811  International Conference on Information Techno...
#
#         ConferenceSeriesNormalizedName                              Doi  \
# 0                                 DISC     10.1007/978-3-662-45174-8_28
# 1                                  ESA     10.1007/978-3-662-44777-2_60
# 2                                ENTER     10.1007/978-3-319-03973-2_13
# 3                                 DEXA         10.1007/3-540-46146-9_77
# 4                               ICAISC              10.1007/11785231_94
# ...                                ...                              ...
# 4409807                          IECON  10.1109/IECON43393.2020.9254316
# 4409808                           BMSB   10.1109/BMSB49480.2020.9379806
# 4409809                            ACC         10.1109/ACC.1988.4172843
# 4409810                         ICASSP      10.1109/ICASSP.2002.1005676
# 4409811                           ICIT     10.1109/ITCA52113.2020.00077
#
#          EstimatedCitation                                      OriginalTitle  \
# 0                       12  The Adaptive Priority Queue with Elimination a...
# 1                       10       Document Retrieval on Repetitive Collections
# 2                       20            SoCoMo Marketing for Travel and Tourism
# 3                        0  Similarity Image Retrieval System Using Hierar...
# 4                       19  Leukemia prediction from gene expression data—...
# ...                    ...                                                ...
# 4409807                  0  Loss Reduction by Synchronous Rectification in...
# 4409808                  0  Data Over Cable Services – Improving the BICM ...
# 4409809                  0  Model Reference Robust Adaptive Control withou...
# 4409810                  0  Missing data speech recognition in reverberant...
# 4409811                  0  Research on Text to Image Based on Generative ...
#
#                                                 PaperTitle  Year
# 0        the adaptive priority queue with elimination a...  2014
# 1             document retrieval on repetitive collections  2014
# 2                  socomo marketing for travel and tourism  2013
# 3        similarity image retrieval system using hierar...  2002
# 4        leukemia prediction from gene expression data ...  2006
# ...                                                    ...   ...
# 4409807  loss reduction by synchronous rectification in...  2020
# 4409808  data over cable services improving the bicm ca...  2020
# 4409809  model reference robust adaptive control withou...  1988
# 4409810  missing data speech recognition in reverberant...  2002
# 4409811  research on text to image based on generative ...  2020
#
# [4409812 rows x 10 columns]

# %% [markdown]
# ## Preparation of the CSV Preprocessed DBLP Dump

# %% [markdown]
# ### Removing the DOI Website Path from the DOI URL (ee Column)

# %% [markdown]
# First we need to fix the rows that have multiple URLs separated by the | character

# %%
for dblp_index, dblp_row in df_dblp.iterrows():

    if str(dblp_row['ee']).split('|').__len__() >= 2:
        df_dblp.at[dblp_index, 'ee'] = dblp_row['ee'].split('|')[1]

# %% [markdown]
# Removing the DOI website path

# %%
df_dblp['doi'] = np.nan
df_dblp.doi = df_dblp.ee.str.lower().str.split('.org/').str[1]

# Column sort
df_dblp = df_dblp.reindex(sorted(df_dblp.columns), axis=1)

df_dblp.loc[:5]

# %% [markdown]
# ### Creation of the DBLP Conference Instance Identifier
# Before we can proceed with the join operations, we first need to create a conference identifier that will allow us to join the conference data between DBLP and MAG.
#
# The chosen identifier is going to be composed in the same way of the ConferenceNormalizedName field of the MAG dump: name of the conference series (lower case) + year.

# %% [markdown]
# #### Extraction of the Conference Series Name from the Column "key"

# %%
df_dblp['ConferenceNormalizedName'] = np.nan
df_dblp.ConferenceNormalizedName = df_dblp.key.str.split('/').str[1]

# Column sort
df_dblp = df_dblp.reindex(sorted(df_dblp.columns), axis=1)
df_dblp.loc[:5]

# %% [markdown]
# #### Fix of the Wrong Conferences Series Names
# The above operation works for the most of the rows. However, there are some special cases that we need to fix manually.

# %% [markdown]
# Fix of the papers that need the extraction from the crossref field:

# %%
crossref_list = ['agp', 'aipl', 'amcc', 'amec', 'bcd', 'biotec', 'calculemus', 'cf', 'cnps', 'corr', 'cw', 'daglib', 'dali', 'dbtel', 'ecoopwException', 'express', 'f-egc', 'icsengt', 'ifip5-5', 'infinity', 'isdt', 'iwlcs', 'npiv', 'wcit', 'isdt', 'dsai', 'aipl', 'dbtel', 'cw']

# %% [markdown]
# Special cases:

# %%
print_counter = 0

for dblp_index, dblp_row in df_dblp.iterrows():

    print_counter += 1
    if print_counter == 25000:
        print(f"Riga numero {dblp_index + 1}")
        print_counter = 0

    fixed = False

    for i in range (0, crossref_list.__len__()):
        if str(dblp_row['crossref']).split('/').__len__() >= 2:
            if crossref_list[i] == str(dblp_row['crossref']).split('/')[1]:
                df_dblp.at[dblp_index, 'ConferenceNormalizedName'] = crossref_list[i]
                fixed = True
                break
    
    if not fixed:
        if "ecoopwException" in str(dblp_row['crossref']):
            df_dblp.at[dblp_index, 'ConferenceNormalizedName'] = "ecoopw"
        elif "icsengt" in str(dblp_row['crossref']):
            df_dblp.at[dblp_index, 'ConferenceNormalizedName'] = "icset"

        if "ali2" in str(dblp_row['key']):
            df_dblp.at[dblp_index, 'ConferenceNormalizedName'] = "ali"
        elif "ictcs2" in str(dblp_row['key']):
            df_dblp.at[dblp_index, 'ConferenceNormalizedName'] = "ictcs"

# %% [markdown]
# #### Adding the Year to the Conference Series Name

# %%
df_dblp.ConferenceNormalizedName = df_dblp.ConferenceNormalizedName + ' ' + df_dblp.year.astype(str)

# %%
df_dblp.loc[:5]

# %% [markdown]
# ### Write of the Join Ready DBLP Dump on Disk

# %%
# Write of the resulting CSV on Disk
df_dblp.to_csv(path_file_export + 'out_dblp_join_ready.csv')
print(f'Successfully Exported the Processed CSV to {path_file_export}out_dblp_join_ready.csv')

# %% [markdown]
# ## Join Between DBLP and MAG

# %% [markdown]
# Rename of the DBLP doi column:

# %%
df_dblp = df_dblp.rename(columns={'doi': 'Doi'})

# %% [markdown]
# Making sure that all dois are in lowercase:

# %%
df_dblp.Doi = df_dblp.Doi.str.lower()
df_mag.Doi = df_mag.Doi.str.lower()

# %% [markdown]
# Now we can proceed with the join and cleaning operations:

# %%
df_mag = pd.merge(df_mag, df_dblp, on=['Doi'], how='outer')

# Combine the conference location columns
df_mag['ConferenceLocation_x'] = df_mag['ConferenceLocation_x'].fillna(df_mag['ConferenceLocation_y'])
df_mag.rename(columns = {'ConferenceLocation_x':'ConferenceLocation'}, inplace=True)
df_mag = df_mag.drop(columns=['ConferenceLocation_y'])

# Combine the conference normalized name columns
df_mag['ConferenceNormalizedName_x'] = df_mag['ConferenceNormalizedName_x'].fillna(df_mag['ConferenceNormalizedName_y'])
df_mag.rename(columns = {'ConferenceNormalizedName_x':'ConferenceNormalizedName'}, inplace=True)
df_mag = df_mag.drop(columns=['ConferenceNormalizedName_y'])

# Combine the year columns
df_mag['Year'] = df_mag['Year'].fillna(df_mag['year'])
df_mag = df_mag.drop(columns=['year'])

# Drop of the DBLP columns that are not needed anymore
df_mag = df_mag.drop(columns=['crossref', 'ee', 'key', 'url'])

# Drop of the MAG columns that are not needed anymore
df_mag = df_mag.drop(columns=['PaperTitle', 'ConferenceSeriesDisplayName', 'ConferenceSeriesNormalizedName'])

# Rename of some columns to remove ambiguity
df_mag.rename(columns={'CitationCount': 'CitationCount_Mag', 'EstimatedCitation': 'CitationCount_MagEstimated'}, inplace=True)

# Column sort
df_mag = df_mag.reindex(sorted(df_mag.columns), axis=1)

# Fix of the year column data type
df_mag = df_mag.astype({"Year": int}) 

df_mag
# Out:
#          CitationCount_Mag  CitationCount_MagEstimated    ConferenceLocation  \
# 0                     12.0                        12.0            Austin, TX
# 1                     10.0                        10.0       Wrocław, Poland
# 2                     20.0                        20.0    Innsbruck, Austria
# 3                      0.0                         0.0      Provence, France
# 4                     19.0                        19.0      Zakopane, Poland
# ...                    ...                         ...                   ...
# 4988315                NaN                         NaN  Thessaloniki, Greece
# 4988316                NaN                         NaN  Thessaloniki, Greece
# 4988317                NaN                         NaN  Thessaloniki, Greece
# 4988318                NaN                         NaN  Thessaloniki, Greece
# 4988319                NaN                         NaN  Thessaloniki, Greece
#
#         ConferenceNormalizedName  \
# 0                      disc 2014
# 1                       esa 2014
# 2                     enter 2013
# 3                      dexa 2002
# 4                    icaisc 2006
# ...                          ...
# 4988315              sapere 2011
# 4988316              sapere 2011
# 4988317              sapere 2011
# 4988318              sapere 2011
# 4988319              sapere 2011
#
#                                            ConferenceTitle  \
# 0        Distributed Computing - 28th International Sym...
# 1        Algorithms - ESA 2014 - 22th Annual European S...
# 2        Information and Communication Technologies in ...
# 3        Database and Expert Systems Applications, 13th...
# 4        Artificial Intelligence and Soft Computing - I...
# ...                                                    ...
# 4988315  Philosophy and Theory of Artificial Intelligen...
# 4988316  Philosophy and Theory of Artificial Intelligen...
# 4988317  Philosophy and Theory of Artificial Intelligen...
# 4988318  Philosophy and Theory of Artificial Intelligen...
# 4988319  Philosophy and Theory of Artificial Intelligen...
#
#                                   Doi  \
# 0        10.1007/978-3-662-45174-8_28
# 1        10.1007/978-3-662-44777-2_60
# 2        10.1007/978-3-319-03973-2_13
# 3            10.1007/3-540-46146-9_77
# 4                 10.1007/11785231_94
# ...                               ...
# 4988315   10.1007/978-3-642-31674-6_9
# 4988316  10.1007/978-3-642-31674-6_20
# 4988317  10.1007/978-3-642-31674-6_25
# 4988318  10.1007/978-3-642-31674-6_12
# 4988319   10.1007/978-3-642-31674-6_3
#
#                                              OriginalTitle  Year
# 0        The Adaptive Priority Queue with Elimination a...  2014
# 1             Document Retrieval on Repetitive Collections  2014
# 2                  SoCoMo Marketing for Travel and Tourism  2013
# 3        Similarity Image Retrieval System Using Hierar...  2002
# 4        Leukemia prediction from gene expression data—...  2006
# ...                                                    ...   ...
# 4988315                                                NaN  2011
# 4988316                                                NaN  2011
# 4988317                                                NaN  2011
# 4988318                                                NaN  2011
# 4988319                                                NaN  2011
#
# [4988320 rows x 8 columns]

# %% [markdown]
# ## Converting the NaN Citations to 0

# %%
df_mag['CitationCount_Mag'] = df_mag['CitationCount_Mag'].fillna(0)
df_mag['CitationCount_MagEstimated'] = df_mag['CitationCount_MagEstimated'].fillna(0)

# %% [markdown]
# Fix of the data type:

# %%
df_mag = df_mag.astype({"CitationCount_Mag": int}) 
df_mag = df_mag.astype({"CitationCount_MagEstimated": int})

# %%
df_mag.loc[:5]
# Out:
#    CitationCount_Mag  CitationCount_MagEstimated  ConferenceLocation  \
# 0                 12                          12          Austin, TX
# 1                 10                          10     Wrocław, Poland
# 2                 20                          20  Innsbruck, Austria
# 3                  0                           0    Provence, France
# 4                 19                          19    Zakopane, Poland
# 5                  4                           4    Lisbon, Portugal
#
#   ConferenceNormalizedName                                    ConferenceTitle  \
# 0                disc 2014  Distributed Computing - 28th International Sym...
# 1                 esa 2014  Algorithms - ESA 2014 - 22th Annual European S...
# 2               enter 2013  Information and Communication Technologies in ...
# 3                dexa 2002  Database and Expert Systems Applications, 13th...
# 4              icaisc 2006  Artificial Intelligence and Soft Computing - I...
# 5            interact 2011  HCI International 2011 - Posters' Extended Abs...
#
#                             Doi  \
# 0  10.1007/978-3-662-45174-8_28
# 1  10.1007/978-3-662-44777-2_60
# 2  10.1007/978-3-319-03973-2_13
# 3      10.1007/3-540-46146-9_77
# 4           10.1007/11785231_94
# 5  10.1007/978-3-642-22095-1_80
#
#                                        OriginalTitle  Year
# 0  The Adaptive Priority Queue with Elimination a...  2014
# 1       Document Retrieval on Repetitive Collections  2014
# 2            SoCoMo Marketing for Travel and Tourism  2013
# 3  Similarity Image Retrieval System Using Hierar...  2002
# 4  Leukemia prediction from gene expression data—...  2006
# 5  Computer Interaction and the Benefits of Socia...  2011

# %% [markdown]
# ## Write of the Final CSV on Disk

# %% [markdown]
# Saving the resulting dataframe on disk in CSV format.

# %%
# Write of the resulting CSV on Disk
df_mag.to_csv(path_file_export + 'out_dblp_and_mag_joined.csv')
print(f'Successfully Exported the Processed CSV to {path_file_export}out_dblp_and_mag_joined.csv')
# Out:
# Successfully Exported the Processed CSV to /Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/out_dblp_and_mag_joined.csv

# %% [markdown]
# Check of the Exported CSV to be sure that everything went fine.

# %%
# Check of the Exported CSV
df_joined_exported_csv = pd.read_csv(path_file_export + 'out_dblp_and_mag_joined.csv', low_memory=False, index_col=[0])
df_joined_exported_csv
# Out:
#          CitationCount_Mag  CitationCount_MagEstimated    ConferenceLocation  \
# 0                       12                          12            Austin, TX
# 1                       10                          10       Wrocław, Poland
# 2                       20                          20    Innsbruck, Austria
# 3                        0                           0      Provence, France
# 4                       19                          19      Zakopane, Poland
# ...                    ...                         ...                   ...
# 4988315                  0                           0  Thessaloniki, Greece
# 4988316                  0                           0  Thessaloniki, Greece
# 4988317                  0                           0  Thessaloniki, Greece
# 4988318                  0                           0  Thessaloniki, Greece
# 4988319                  0                           0  Thessaloniki, Greece
#
#         ConferenceNormalizedName  \
# 0                      disc 2014
# 1                       esa 2014
# 2                     enter 2013
# 3                      dexa 2002
# 4                    icaisc 2006
# ...                          ...
# 4988315              sapere 2011
# 4988316              sapere 2011
# 4988317              sapere 2011
# 4988318              sapere 2011
# 4988319              sapere 2011
#
#                                            ConferenceTitle  \
# 0        Distributed Computing - 28th International Sym...
# 1        Algorithms - ESA 2014 - 22th Annual European S...
# 2        Information and Communication Technologies in ...
# 3        Database and Expert Systems Applications, 13th...
# 4        Artificial Intelligence and Soft Computing - I...
# ...                                                    ...
# 4988315  Philosophy and Theory of Artificial Intelligen...
# 4988316  Philosophy and Theory of Artificial Intelligen...
# 4988317  Philosophy and Theory of Artificial Intelligen...
# 4988318  Philosophy and Theory of Artificial Intelligen...
# 4988319  Philosophy and Theory of Artificial Intelligen...
#
#                                   Doi  \
# 0        10.1007/978-3-662-45174-8_28
# 1        10.1007/978-3-662-44777-2_60
# 2        10.1007/978-3-319-03973-2_13
# 3            10.1007/3-540-46146-9_77
# 4                 10.1007/11785231_94
# ...                               ...
# 4988315   10.1007/978-3-642-31674-6_9
# 4988316  10.1007/978-3-642-31674-6_20
# 4988317  10.1007/978-3-642-31674-6_25
# 4988318  10.1007/978-3-642-31674-6_12
# 4988319   10.1007/978-3-642-31674-6_3
#
#                                              OriginalTitle  Year
# 0        The Adaptive Priority Queue with Elimination a...  2014
# 1             Document Retrieval on Repetitive Collections  2014
# 2                  SoCoMo Marketing for Travel and Tourism  2013
# 3        Similarity Image Retrieval System Using Hierar...  2002
# 4        Leukemia prediction from gene expression data—...  2006
# ...                                                    ...   ...
# 4988315                                                NaN  2011
# 4988316                                                NaN  2011
# 4988317                                                NaN  2011
# 4988318                                                NaN  2011
# 4988319                                                NaN  2011
#
# [4988320 rows x 8 columns]
