# %% [markdown]
# # Preprocess Microsoft Academics Graph (MAG) Dataset
#
# Jupyter Notebook for the preprocessing of the Microsoft Academics Graph (MAG) dump.
#
# For this process, the following CSV files are needed: ```ConferenceInstances.txt```, ```ConferenceSeries.txt```, ```Papers.txt```.
# The above files can be found here: https://archive.org/download/mag-2021-06-07/mag/
#
# In particular, the following operations are going to be executed:
# * Opening of ConferenceInstances and ConferenceSeries CSVs
# * Drop of the useless columns
# * Chuncked Processing of the Papers CSV
#     * Drop of the useless columns
#     * Drop of papers without DOI
#     * Drop of papers from journals and books rows
# * Merge with the processed conferences data
# * Fix of some mismatched data types
#
# Lastly, the entire preprocessed dump is going to be saved on disk in CSV format

# %%
# Libraries Import
import pandas as pd    

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## File Paths
# Please set your working directory paths.

# %%
# ******************* PATHS ********************+

# Dumps Directory Path
path_file_import = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Import/'

# CSV Exports Directory Path
path_file_export = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/'

# %% [markdown]
# ### Use a Previuously Preprocessed Papers CSV
# This can be really useful to save some time using a previously elaborated CSV file. We don't need to repeat the same operations!
#
# **Note**: the CSV needs to be in the same format of the one generated with this script

# %%
# Use a Previuously Preprocessed Papers CSV
#
# This can be really useful to save some time using a previously elaborated
# CSV file. We don't need to repeat the same operations!
#
# Note: the CSV needs to be in the same format of the one generated with this script
read_preprocessed_papers = True
preprocessed_papers_csv_path = r'/Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/out_mag_papers.csv'

# %% [markdown]
# ## Preprocess of Conference Instances CSV

# %%
# ******************* CONFERENCE INSTANCES ********************

# Read of the Conference Instances File

# The column names follow the MAG' scheme official documentation
df_mag_conf_instances_col_names = ['ConferenceInstanceID', 'NormalizedName', 'DisplayName', 'ConferenceSeriesID', 'Location', 'OfficialUrl', 'StartDate', 'EndDate', 'AbstractRegistrationDate', 'SubmissionDeadlineDate', 'NotificationDueDate', 'FinalVersionDueDate', 'PageCount', 'PaperFamilyCount', 'CitationCount', 'Latitude', 'Longitude', 'CreatedDate']

df_mag_conf_instances = pd.read_csv(path_file_import + 'ConferenceInstances.txt', sep='\t', names=df_mag_conf_instances_col_names)
df_mag_conf_instances
# Out:
#        ConferenceInstanceID NormalizedName   DisplayName  ConferenceSeriesID  \
# 0                   7785157      time 2008     TIME 2008          2624631009
# 1                  15420687      ipmu 2008     IPMU 2008          1128239323
# 2                  16798864      wosn 2010     WOSN 2010          2756885533
# 3                  18230910      sasn 2009     SASN 2009          1128894334
# 4                  31227610   eurocon 2011  EUROCON 2011          1190350587
# ...                     ...            ...           ...                 ...
# 16454            2890348533       icn 2019      ICN 2019          1147859159
# 16455            2890856803     ismco'2019    ISMCO'2019          2898428697
# 16456            2891744759         ro2018        RO2018          2898131225
# 16457            2892113557     icccn 2019    ICCCN 2019          1137850760
# 16458            3114689490   sigdial 2021  SIGDIAL 2021          2724712181
#
#                         Location  \
# 0               Montreal, Canada
# 1                  Malaga, Spain
# 2                Boston, MA, USA
# 3      Saint Petersburg (Russia)
# 4               Lisbon, Portugal
# ...                          ...
# 16454            Valencia, Spain
# 16455         Incline Village,us
# 16456               Amsterdam,nl
# 16457            Valencia, Spain
# 16458                  Singapore
#
#                                              OfficialUrl   StartDate  \
# 0                               http://www.time2008.org/  2008-06-16
# 1                         http://www.gimac.uma.es/ipmu08  2008-06-22
# 2               http://www.usenix.org/events/wosn10/cfp/  2010-06-22
# 3                    http://www.ieee-sasn.org/index.html  2009-10-12
# 4                          http://www.eurocon2011.it.pt/  2011-04-27
# ...                                                  ...         ...
# 16454        http://iaria.org/conferences2019/ICN19.html  2019-03-24
# 16455                               http://www.ismco.net  2019-04-29
# 16456              http://www.researchobject.org/ro2018/  2018-10-29
# 16457                           http://icccn.org/icccn19  2019-07-29
# 16458  https://www.sigdial.org/files/workshops/confer...  2021-07-29
#
#           EndDate AbstractRegistrationDate SubmissionDeadlineDate  \
# 0      2008-06-18                      NaN             2008-01-11
# 1      2008-06-27                      NaN             2007-12-07
# 2      2010-06-22                      NaN             2010-02-25
# 3      2009-10-14               2009-06-19             2009-06-26
# 4      2011-04-29                      NaN             2010-10-30
# ...           ...                      ...                    ...
# 16454  2019-03-28                      NaN             2018-11-10
# 16455  2019-05-01                      NaN             2018-12-17
# 16456  2018-10-29               2018-07-15             2018-07-15
# 16457  2019-08-01                      NaN             2019-03-01
# 16458  2021-07-31                      NaN             2021-01-15
#
#       NotificationDueDate FinalVersionDueDate  PageCount  PaperFamilyCount  \
# 0                     NaN                 NaN         23                23
# 1                     NaN                 NaN          5                 5
# 2              2010-04-30          2010-05-25          9                 9
# 3              2009-07-31          2009-09-11          0                 0
# 4              2011-01-30          2011-02-28        279               279
# ...                   ...                 ...        ...               ...
# 16454          2019-01-10          2019-02-04        179               179
# 16455                 NaN                 NaN          6                 6
# 16456                 NaN                 NaN          1                 1
# 16457          2019-04-26          2019-05-10        126               126
# 16458                 NaN                 NaN          0                 0
#
#        CitationCount   Latitude   Longitude CreatedDate
# 0                319  45.512400  -73.554680  2016-06-24
# 1                 45  36.718320   -4.420160  2016-06-24
# 2                666  42.358660  -71.056740  2016-06-24
# 3                  0  59.933180   30.306030  2016-06-24
# 4                864  38.725700   -9.150250  2016-06-24
# ...              ...        ...         ...         ...
# 16454            180  39.468990   -0.376860  2018-09-27
# 16455             12  39.250090 -119.959267  2018-09-27
# 16456              0  52.353218    5.002769  2018-09-27
# 16457            224  39.468990   -0.376860  2018-09-27
# 16458              0   1.290160  103.852000  2021-01-05
#
# [16459 rows x 18 columns]

# %% [markdown]
# Here the useless columns are going to be removed from the dataframe.

# %%
# Drop of Conference Instances' Useless Columns
df_mag_conf_instances = df_mag_conf_instances.drop(columns=['OfficialUrl', 'AbstractRegistrationDate', 'SubmissionDeadlineDate', 'NotificationDueDate', 'FinalVersionDueDate', 'PageCount', 'PaperFamilyCount', 'CitationCount', 'Latitude', 'Longitude', 'CreatedDate', 'StartDate', 'EndDate'])
df_mag_conf_instances
# Out:
#        ConferenceInstanceID NormalizedName   DisplayName  ConferenceSeriesID  \
# 0                   7785157      time 2008     TIME 2008          2624631009
# 1                  15420687      ipmu 2008     IPMU 2008          1128239323
# 2                  16798864      wosn 2010     WOSN 2010          2756885533
# 3                  18230910      sasn 2009     SASN 2009          1128894334
# 4                  31227610   eurocon 2011  EUROCON 2011          1190350587
# ...                     ...            ...           ...                 ...
# 16454            2890348533       icn 2019      ICN 2019          1147859159
# 16455            2890856803     ismco'2019    ISMCO'2019          2898428697
# 16456            2891744759         ro2018        RO2018          2898131225
# 16457            2892113557     icccn 2019    ICCCN 2019          1137850760
# 16458            3114689490   sigdial 2021  SIGDIAL 2021          2724712181
#
#                         Location
# 0               Montreal, Canada
# 1                  Malaga, Spain
# 2                Boston, MA, USA
# 3      Saint Petersburg (Russia)
# 4               Lisbon, Portugal
# ...                          ...
# 16454            Valencia, Spain
# 16455         Incline Village,us
# 16456               Amsterdam,nl
# 16457            Valencia, Spain
# 16458                  Singapore
#
# [16459 rows x 5 columns]

# %% [markdown]
# Column rename to remove ambiguity for the future joins

# %%
# Column rename to remove ambiguity for the future joins
df_mag_conf_instances.rename(columns={'NormalizedName': 'ConferenceNormalizedName', 'DisplayName': 'ConferenceDisplayName', 'Location': 'ConferenceLocation'}, inplace=True)
df_mag_conf_instances
# Out:
#        ConferenceInstanceID ConferenceNormalizedName ConferenceDisplayName  \
# 0                   7785157                time 2008             TIME 2008
# 1                  15420687                ipmu 2008             IPMU 2008
# 2                  16798864                wosn 2010             WOSN 2010
# 3                  18230910                sasn 2009             SASN 2009
# 4                  31227610             eurocon 2011          EUROCON 2011
# ...                     ...                      ...                   ...
# 16454            2890348533                 icn 2019              ICN 2019
# 16455            2890856803               ismco'2019            ISMCO'2019
# 16456            2891744759                   ro2018                RO2018
# 16457            2892113557               icccn 2019            ICCCN 2019
# 16458            3114689490             sigdial 2021          SIGDIAL 2021
#
#        ConferenceSeriesID         ConferenceLocation
# 0              2624631009           Montreal, Canada
# 1              1128239323              Malaga, Spain
# 2              2756885533            Boston, MA, USA
# 3              1128894334  Saint Petersburg (Russia)
# 4              1190350587           Lisbon, Portugal
# ...                   ...                        ...
# 16454          1147859159            Valencia, Spain
# 16455          2898428697         Incline Village,us
# 16456          2898131225               Amsterdam,nl
# 16457          1137850760            Valencia, Spain
# 16458          2724712181                  Singapore
#
# [16459 rows x 5 columns]

# %% [markdown]
# ## Preprocess of Conference Series CSV

# %%
# ******************* CONFERENCE SERIES ********************

# Read of the Conference Series File

# The column names follow the MAG' scheme official documentation
df_mag_conf_series_col_names = ['ConferenceSeriesID', 'Rank', 'NormalizedName', 'DisplayName', 'PaperCount', 'PaperFamilyCount', 'CitationCount', 'CreatedDate']

df_mag_conf_series = pd.read_csv(path_file_import + 'ConferenceSeries.txt', sep='\t', names=df_mag_conf_series_col_names)
df_mag_conf_series
# Out:
#       ConferenceSeriesID   Rank  NormalizedName  \
# 0             1134804816  12817           ICIDS
# 1             1165160117  14777         SWAT4LS
# 2             1192093291  12271      TRIDENTCOM
# 3             1199066382  10155  BIOINFORMATICS
# 4             1201746639  15567             AIS
# ...                  ...    ...             ...
# 4533          2754809603  14461            IPSS
# 4534          2756271167  13527            ECMS
# 4535          2756896743  17566             CAI
# 4536          2757378734  15053      UPGRADE-CN
# 4537          2898205804  18639          ER(ZR)
#
#                                             DisplayName  PaperCount  \
# 0     International Conference on Interactive Digita...         611
# 1     Semantic Web Applications and Tools for Life S...          85
# 2     Testbeds and Research Infrastructures for the ...         571
# 3            International Conference on Bioinformatics       10692
# 4                    Autonomous and Intelligent Systems         165
# ...                                                 ...         ...
# 4533         IEEE International Power Sources Symposium         101
# 4534    European Conference on Modelling and Simulation         283
# 4535                Conference on Algebraic Informatics         124
# 4536  Use of P2P, GRID and Agents for the Developmen...          40
# 4537  International Conference Electromechanics and ...           2
#
#       PaperFamilyCount  CitationCount CreatedDate
# 0                  610           2945  2016-06-24
# 1                   85            213  2016-06-24
# 2                  571           5174  2016-06-24
# 3                10692          17021  2016-06-24
# 4                  165           1002  2016-06-24
# ...                ...            ...         ...
# 4533               101            188  2017-09-25
# 4534               283            915  2017-09-25
# 4535               124            567  2017-10-06
# 4536                40            314  2017-10-06
# 4537                 2              5  2018-11-02
#
# [4538 rows x 8 columns]

# %% [markdown]
# Here the useless columns are going to be removed from the dataframe.

# %%
# Drop of Conference Series' Useless Columns
df_mag_conf_series = df_mag_conf_series.drop(columns=['Rank', 'PaperCount', 'PaperFamilyCount', 'CitationCount', 'CreatedDate'])
df_mag_conf_series
# Out:
#       ConferenceSeriesID  NormalizedName  \
# 0             1134804816           ICIDS
# 1             1165160117         SWAT4LS
# 2             1192093291      TRIDENTCOM
# 3             1199066382  BIOINFORMATICS
# 4             1201746639             AIS
# ...                  ...             ...
# 4533          2754809603            IPSS
# 4534          2756271167            ECMS
# 4535          2756896743             CAI
# 4536          2757378734      UPGRADE-CN
# 4537          2898205804          ER(ZR)
#
#                                             DisplayName
# 0     International Conference on Interactive Digita...
# 1     Semantic Web Applications and Tools for Life S...
# 2     Testbeds and Research Infrastructures for the ...
# 3            International Conference on Bioinformatics
# 4                    Autonomous and Intelligent Systems
# ...                                                 ...
# 4533         IEEE International Power Sources Symposium
# 4534    European Conference on Modelling and Simulation
# 4535                Conference on Algebraic Informatics
# 4536  Use of P2P, GRID and Agents for the Developmen...
# 4537  International Conference Electromechanics and ...
#
# [4538 rows x 3 columns]

# %% [markdown]
# Column rename to remove ambiguity for the future joins

# %%
# Column rename to remove ambiguity for the future joins
df_mag_conf_series.rename(columns={'NormalizedName': 'ConferenceSeriesNormalizedName', 'DisplayName': 'ConferenceSeriesDisplayName'}, inplace=True)
df_mag_conf_series
# Out:
#       ConferenceSeriesID ConferenceSeriesNormalizedName  \
# 0             1134804816                          ICIDS
# 1             1165160117                        SWAT4LS
# 2             1192093291                     TRIDENTCOM
# 3             1199066382                 BIOINFORMATICS
# 4             1201746639                            AIS
# ...                  ...                            ...
# 4533          2754809603                           IPSS
# 4534          2756271167                           ECMS
# 4535          2756896743                            CAI
# 4536          2757378734                     UPGRADE-CN
# 4537          2898205804                         ER(ZR)
#
#                             ConferenceSeriesDisplayName
# 0     International Conference on Interactive Digita...
# 1     Semantic Web Applications and Tools for Life S...
# 2     Testbeds and Research Infrastructures for the ...
# 3            International Conference on Bioinformatics
# 4                    Autonomous and Intelligent Systems
# ...                                                 ...
# 4533         IEEE International Power Sources Symposium
# 4534    European Conference on Modelling and Simulation
# 4535                Conference on Algebraic Informatics
# 4536  Use of P2P, GRID and Agents for the Developmen...
# 4537  International Conference Electromechanics and ...
#
# [4538 rows x 3 columns]

# %% [markdown]
# ## Preprocess of Papers CSV
# The Papers CSV is going to be processed in chunks, due to its size.
#
# The following operations are going to be executed:
# * Drop of the useless columns
# * Filtering of papers without DOI
# * Filtering papers that are not related to conferences
# * Drop of the doctype column
# * Write of the processed file on disk (in CSV format)

# %%
# ******************* PAPERS ********************

# Read of previously prerocessed CSV
df_mag_papers = None
if read_preprocessed_papers:
    df_mag_papers = pd.read_csv(preprocessed_papers_csv_path, low_memory=False, index_col=0)
else:
    # The Papers CSV is going to be processed in chunks, due to its size

    # The column names follow the MAG' scheme official documentation
    df_mag_papers_col_names = ['PaperID', 'Rank', 'Doi', 'DocType', 'PaperTitle', 'OriginalTitle', 'BookTitle', 'Year', 'Date', 'OnlineDate', 'Publisher', 'JournalID', 'ConferenceSeriesID', 'ConferenceInstanceID', 'Volume', 'Issue', 'FirstPage', 'LastPage', 'ReferenceCount', 'CitationCount', 'EstimatedCitation', 'OriginalVenue', 'FamilyID', 'FamilyRank', 'Retracion', 'CreatedDate']

    # List of processed chunks.
    df_mag_papers_list_of_chunks = list()

    # Define of the chunk size
    chunksize = 10 ** 7

    count = 1
    with pd.read_csv(path_file_import + 'Papers.txt', sep='\t', chunksize=chunksize, low_memory=False, on_bad_lines='skip', names=df_mag_papers_col_names) as reader:
        for chunk in reader:

            # Drop of the useless columns
            chunk = chunk.drop(columns=['Rank', 'OnlineDate', 'Publisher', 'Volume', 'Issue', 'FirstPage', 'LastPage', 'ReferenceCount', 'OriginalVenue', 'FamilyID', 'FamilyRank', 'Retracion', 'CreatedDate', 'JournalID', 'BookTitle', 'Date'])

            # Filtering of papers without DOI
            chunk = chunk.dropna(subset = ['Doi'])

            # Filtering papers that are not related to conferences
            chunk = chunk[chunk.DocType == 'Conference']

            # Drop of the doctype column
            chunk = chunk.drop(columns=['DocType'])

            # Insert of the resulting chunk in the list 
            df_mag_papers_list_of_chunks.append(chunk)

            print(f'Successfully processed chunk {count} out of around {260000000 / chunksize}')
            count += 1
            break

    # Concatenation of the processed chunks
    df_mag_papers = pd.concat(df_mag_papers_list_of_chunks)

    # Empty the list to free some memory
    df_mag_papers_list_of_chunks = list()

    # Write of the resulting CSV on Disk
    df_mag_papers.to_csv(path_file_export + 'out_mag_papers.csv')
    print(f'Successfully Exported the Preprocessed Papers CSV to {path_file_export}out_mag_papers.csv')

df_mag_papers
# Out:
#               PaperID                              Doi  \
# 37           14558443     10.1007/978-3-662-45174-8_28
# 39           15354235     10.1007/978-3-662-44777-2_60
# 68           24327294     10.1007/978-3-319-03973-2_13
# 197          60437532         10.1007/3-540-46146-9_77
# 666         198056957              10.1007/11785231_94
# ...               ...                              ...
# 259718386  3102242761  10.1109/IECON43393.2020.9254316
# 259718500  3136855299   10.1109/BMSB49480.2020.9379806
# 259718537  3145351916         10.1109/ACC.1988.4172843
# 259718570  3151696876      10.1109/ICASSP.2002.1005676
# 259718611  3162646375     10.1109/ITCA52113.2020.00077
#
#                                                   PaperTitle  \
# 37         the adaptive priority queue with elimination a...
# 39              document retrieval on repetitive collections
# 68                   socomo marketing for travel and tourism
# 197        similarity image retrieval system using hierar...
# 666        leukemia prediction from gene expression data ...
# ...                                                      ...
# 259718386  loss reduction by synchronous rectification in...
# 259718500  data over cable services improving the bicm ca...
# 259718537  model reference robust adaptive control withou...
# 259718570  missing data speech recognition in reverberant...
# 259718611  research on text to image based on generative ...
#
#                                                OriginalTitle    Year  \
# 37         The Adaptive Priority Queue with Elimination a...  2014.0
# 39              Document Retrieval on Repetitive Collections  2014.0
# 68                   SoCoMo Marketing for Travel and Tourism  2013.0
# 197        Similarity Image Retrieval System Using Hierar...  2002.0
# 666        Leukemia prediction from gene expression data—...  2006.0
# ...                                                      ...     ...
# 259718386  Loss Reduction by Synchronous Rectification in...  2020.0
# 259718500  Data Over Cable Services – Improving the BICM ...  2020.0
# 259718537  Model Reference Robust Adaptive Control withou...  1988.0
# 259718570  Missing data speech recognition in reverberant...  2002.0
# 259718611  Research on Text to Image Based on Generative ...  2020.0
#
#            ConferenceSeriesID  ConferenceInstanceID  CitationCount  \
# 37               1.131603e+09             4038532.0           12.0
# 39               1.154039e+09           157008481.0           10.0
# 68               1.196984e+09                   NaN           20.0
# 197              1.192665e+09                   NaN            0.0
# 666              1.176896e+09                   NaN           19.0
# ...                       ...                   ...            ...
# 259718386        2.623572e+09                   NaN            0.0
# 259718500        2.623662e+09                   NaN            0.0
# 259718537        2.238538e+09                   NaN            0.0
# 259718570        1.121228e+09                   NaN            0.0
# 259718611        2.622834e+09                   NaN            0.0
#
#           EstimatedCitation
# 37                       12
# 39                       10
# 68                       20
# 197                       0
# 666                      19
# ...                     ...
# 259718386                 0
# 259718500                 0
# 259718537                 0
# 259718570                 0
# 259718611                 0
#
# [4409816 rows x 9 columns]

# %% [markdown]
# ## Merge of Conferences and Papers Data

# %%
# ******************* MERGE OF CONFERENCES AND PAPERS DATA ********************

# Merge of conferences and papers data over the conferenceseries id columnn to get the conference series name
# The papers' row that will not match will be preserved
df_mag_preprocessed = pd.merge(df_mag_papers, df_mag_conf_series, on=['ConferenceSeriesID'], how='left')

# Merge of conferences and papers data over the conferenceinstances id columnn
# The papers' row that will not match will be preserved
df_mag_preprocessed = pd.merge(df_mag_preprocessed, df_mag_conf_instances, on=['ConferenceInstanceID'], how='left')

# Drop of the duplicated columns
df_mag_preprocessed = df_mag_preprocessed.drop(columns=['ConferenceSeriesID_y'])
df_mag_preprocessed.rename(columns = {'ConferenceSeriesID_x':'ConferenceSeriesID'}, inplace=True)

# Removing broken data (four records seems to have mismatched types in some columns)
df_mag_preprocessed = df_mag_preprocessed.dropna(subset = ['CitationCount'])

df_mag_preprocessed
# Out:
#             PaperID                              Doi  \
# 0          14558443     10.1007/978-3-662-45174-8_28
# 1          15354235     10.1007/978-3-662-44777-2_60
# 2          24327294     10.1007/978-3-319-03973-2_13
# 3          60437532         10.1007/3-540-46146-9_77
# 4         198056957              10.1007/11785231_94
# ...             ...                              ...
# 4409811  3102242761  10.1109/IECON43393.2020.9254316
# 4409812  3136855299   10.1109/BMSB49480.2020.9379806
# 4409813  3145351916         10.1109/ACC.1988.4172843
# 4409814  3151696876      10.1109/ICASSP.2002.1005676
# 4409815  3162646375     10.1109/ITCA52113.2020.00077
#
#                                                 PaperTitle  \
# 0        the adaptive priority queue with elimination a...
# 1             document retrieval on repetitive collections
# 2                  socomo marketing for travel and tourism
# 3        similarity image retrieval system using hierar...
# 4        leukemia prediction from gene expression data ...
# ...                                                    ...
# 4409811  loss reduction by synchronous rectification in...
# 4409812  data over cable services improving the bicm ca...
# 4409813  model reference robust adaptive control withou...
# 4409814  missing data speech recognition in reverberant...
# 4409815  research on text to image based on generative ...
#
#                                              OriginalTitle    Year  \
# 0        The Adaptive Priority Queue with Elimination a...  2014.0
# 1             Document Retrieval on Repetitive Collections  2014.0
# 2                  SoCoMo Marketing for Travel and Tourism  2013.0
# 3        Similarity Image Retrieval System Using Hierar...  2002.0
# 4        Leukemia prediction from gene expression data—...  2006.0
# ...                                                    ...     ...
# 4409811  Loss Reduction by Synchronous Rectification in...  2020.0
# 4409812  Data Over Cable Services – Improving the BICM ...  2020.0
# 4409813  Model Reference Robust Adaptive Control withou...  1988.0
# 4409814  Missing data speech recognition in reverberant...  2002.0
# 4409815  Research on Text to Image Based on Generative ...  2020.0
#
#          ConferenceSeriesID  ConferenceInstanceID  CitationCount  \
# 0              1.131603e+09             4038532.0           12.0
# 1              1.154039e+09           157008481.0           10.0
# 2              1.196984e+09                   NaN           20.0
# 3              1.192665e+09                   NaN            0.0
# 4              1.176896e+09                   NaN           19.0
# ...                     ...                   ...            ...
# 4409811        2.623572e+09                   NaN            0.0
# 4409812        2.623662e+09                   NaN            0.0
# 4409813        2.238538e+09                   NaN            0.0
# 4409814        1.121228e+09                   NaN            0.0
# 4409815        2.622834e+09                   NaN            0.0
#
#         EstimatedCitation ConferenceSeriesNormalizedName  \
# 0                      12                           DISC
# 1                      10                            ESA
# 2                      20                          ENTER
# 3                       0                           DEXA
# 4                      19                         ICAISC
# ...                   ...                            ...
# 4409811                 0                          IECON
# 4409812                 0                           BMSB
# 4409813                 0                            ACC
# 4409814                 0                         ICASSP
# 4409815                 0                           ICIT
#
#                                ConferenceSeriesDisplayName  \
# 0         International Symposium on Distributed Computing
# 1                         European Symposium on Algorithms
# 2        Information and Communication Technologies in ...
# 3                 Database and Expert Systems Applications
# 4        International Conference on Artificial Intelli...
# ...                                                    ...
# 4409811   Conference of the Industrial Electronics Society
# 4409812  International Symposium on Broadband Multimedi...
# 4409813                        American Control Conference
# 4409814  International Conference on Acoustics, Speech,...
# 4409815  International Conference on Information Techno...
#
#         ConferenceNormalizedName ConferenceDisplayName ConferenceLocation
# 0                      disc 2014             DISC 2014         Austin, TX
# 1                       esa 2014              ESA 2014    Wrocław, Poland
# 2                            NaN                   NaN                NaN
# 3                            NaN                   NaN                NaN
# 4                            NaN                   NaN                NaN
# ...                          ...                   ...                ...
# 4409811                      NaN                   NaN                NaN
# 4409812                      NaN                   NaN                NaN
# 4409813                      NaN                   NaN                NaN
# 4409814                      NaN                   NaN                NaN
# 4409815                      NaN                   NaN                NaN
#
# [4409812 rows x 14 columns]

# %% [markdown]
# ## Fix of the Mismatched Data Type

# %% [markdown]
# Fix of the year data type, that has been interpreted as a float.

# %%
type(df_mag_preprocessed.iloc[:1]["Year"][0])
# Out:
# numpy.float64

# %%
df_mag_preprocessed = df_mag_preprocessed.astype({"Year": int}, errors='raise') 
df_mag_preprocessed.iloc[:3]
# Out:
#     PaperID                           Doi  \
# 0  14558443  10.1007/978-3-662-45174-8_28
# 1  15354235  10.1007/978-3-662-44777-2_60
# 2  24327294  10.1007/978-3-319-03973-2_13
#
#                                           PaperTitle  \
# 0  the adaptive priority queue with elimination a...
# 1       document retrieval on repetitive collections
# 2            socomo marketing for travel and tourism
#
#                                        OriginalTitle  Year  \
# 0  The Adaptive Priority Queue with Elimination a...  2014
# 1       Document Retrieval on Repetitive Collections  2014
# 2            SoCoMo Marketing for Travel and Tourism  2013
#
#    ConferenceSeriesID  ConferenceInstanceID  CitationCount EstimatedCitation  \
# 0        1.131603e+09             4038532.0           12.0                12
# 1        1.154039e+09           157008481.0           10.0                10
# 2        1.196984e+09                   NaN           20.0                20
#
#   ConferenceSeriesNormalizedName  \
# 0                           DISC
# 1                            ESA
# 2                          ENTER
#
#                          ConferenceSeriesDisplayName ConferenceNormalizedName  \
# 0   International Symposium on Distributed Computing                disc 2014
# 1                   European Symposium on Algorithms                 esa 2014
# 2  Information and Communication Technologies in ...                      NaN
#
#   ConferenceDisplayName ConferenceLocation
# 0             DISC 2014         Austin, TX
# 1              ESA 2014    Wrocław, Poland
# 2                   NaN                NaN

# %% [markdown]
# Fix of the CitationCount data type, that has been interpreted as a float.

# %%
type(df_mag_preprocessed.iloc[:1]["CitationCount"][0])
# Out:
# numpy.float64

# %%
df_mag_preprocessed = df_mag_preprocessed.astype({"CitationCount": int}, errors='raise') 
df_mag_preprocessed.iloc[:3]
# Out:
#     PaperID                           Doi  \
# 0  14558443  10.1007/978-3-662-45174-8_28
# 1  15354235  10.1007/978-3-662-44777-2_60
# 2  24327294  10.1007/978-3-319-03973-2_13
#
#                                           PaperTitle  \
# 0  the adaptive priority queue with elimination a...
# 1       document retrieval on repetitive collections
# 2            socomo marketing for travel and tourism
#
#                                        OriginalTitle  Year  \
# 0  The Adaptive Priority Queue with Elimination a...  2014
# 1       Document Retrieval on Repetitive Collections  2014
# 2            SoCoMo Marketing for Travel and Tourism  2013
#
#    ConferenceSeriesID  ConferenceInstanceID  CitationCount EstimatedCitation  \
# 0        1.131603e+09             4038532.0             12                12
# 1        1.154039e+09           157008481.0             10                10
# 2        1.196984e+09                   NaN             20                20
#
#   ConferenceSeriesNormalizedName  \
# 0                           DISC
# 1                            ESA
# 2                          ENTER
#
#                          ConferenceSeriesDisplayName ConferenceNormalizedName  \
# 0   International Symposium on Distributed Computing                disc 2014
# 1                   European Symposium on Algorithms                 esa 2014
# 2  Information and Communication Technologies in ...                      NaN
#
#   ConferenceDisplayName ConferenceLocation
# 0             DISC 2014         Austin, TX
# 1              ESA 2014    Wrocław, Poland
# 2                   NaN                NaN

# %% [markdown]
# ## Write of the Final CSV on Disk

# %%
# Write of the resulting CSV on Disk
df_mag_preprocessed.to_csv(path_file_export + 'out_mag_citations_count_and_conferences.csv')
print(f'Successfully Exported the Preprocessed CSV to {path_file_export}out_mag_citations_count_and_conferences.csv')
# Out:
# Successfully Exported the Preprocessed CSV to /Users/marcoterzulli/File/Scuola Local/Magistrale/Materiale Corsi Attuali/Tirocinio/Cartella di Lavoro/Archivi Dump di Lavoro/Export/out_mag_citations_count_and_conferences.csv

# %% [markdown]
# Check of the Exported CSV to be sure that everything went fine.

# %%
# Check of the Exported CSV
df_mag_exported_csv = pd.read_csv(path_file_export + 'out_mag_citations_count_and_conferences.csv', low_memory=False)
df_mag_exported_csv
# Out:
#          Unnamed: 0     PaperID                              Doi  \
# 0                 0    14558443     10.1007/978-3-662-45174-8_28
# 1                 1    15354235     10.1007/978-3-662-44777-2_60
# 2                 2    24327294     10.1007/978-3-319-03973-2_13
# 3                 3    60437532         10.1007/3-540-46146-9_77
# 4                 4   198056957              10.1007/11785231_94
# ...             ...         ...                              ...
# 4409807     4409811  3102242761  10.1109/IECON43393.2020.9254316
# 4409808     4409812  3136855299   10.1109/BMSB49480.2020.9379806
# 4409809     4409813  3145351916         10.1109/ACC.1988.4172843
# 4409810     4409814  3151696876      10.1109/ICASSP.2002.1005676
# 4409811     4409815  3162646375     10.1109/ITCA52113.2020.00077
#
#                                                 PaperTitle  \
# 0        the adaptive priority queue with elimination a...
# 1             document retrieval on repetitive collections
# 2                  socomo marketing for travel and tourism
# 3        similarity image retrieval system using hierar...
# 4        leukemia prediction from gene expression data ...
# ...                                                    ...
# 4409807  loss reduction by synchronous rectification in...
# 4409808  data over cable services improving the bicm ca...
# 4409809  model reference robust adaptive control withou...
# 4409810  missing data speech recognition in reverberant...
# 4409811  research on text to image based on generative ...
#
#                                              OriginalTitle  Year  \
# 0        The Adaptive Priority Queue with Elimination a...  2014
# 1             Document Retrieval on Repetitive Collections  2014
# 2                  SoCoMo Marketing for Travel and Tourism  2013
# 3        Similarity Image Retrieval System Using Hierar...  2002
# 4        Leukemia prediction from gene expression data—...  2006
# ...                                                    ...   ...
# 4409807  Loss Reduction by Synchronous Rectification in...  2020
# 4409808  Data Over Cable Services – Improving the BICM ...  2020
# 4409809  Model Reference Robust Adaptive Control withou...  1988
# 4409810  Missing data speech recognition in reverberant...  2002
# 4409811  Research on Text to Image Based on Generative ...  2020
#
#          ConferenceSeriesID  ConferenceInstanceID  CitationCount  \
# 0              1.131603e+09             4038532.0             12
# 1              1.154039e+09           157008481.0             10
# 2              1.196984e+09                   NaN             20
# 3              1.192665e+09                   NaN              0
# 4              1.176896e+09                   NaN             19
# ...                     ...                   ...            ...
# 4409807        2.623572e+09                   NaN              0
# 4409808        2.623662e+09                   NaN              0
# 4409809        2.238538e+09                   NaN              0
# 4409810        1.121228e+09                   NaN              0
# 4409811        2.622834e+09                   NaN              0
#
#          EstimatedCitation ConferenceSeriesNormalizedName  \
# 0                       12                           DISC
# 1                       10                            ESA
# 2                       20                          ENTER
# 3                        0                           DEXA
# 4                       19                         ICAISC
# ...                    ...                            ...
# 4409807                  0                          IECON
# 4409808                  0                           BMSB
# 4409809                  0                            ACC
# 4409810                  0                         ICASSP
# 4409811                  0                           ICIT
#
#                                ConferenceSeriesDisplayName  \
# 0         International Symposium on Distributed Computing
# 1                         European Symposium on Algorithms
# 2        Information and Communication Technologies in ...
# 3                 Database and Expert Systems Applications
# 4        International Conference on Artificial Intelli...
# ...                                                    ...
# 4409807   Conference of the Industrial Electronics Society
# 4409808  International Symposium on Broadband Multimedi...
# 4409809                        American Control Conference
# 4409810  International Conference on Acoustics, Speech,...
# 4409811  International Conference on Information Techno...
#
#         ConferenceNormalizedName ConferenceDisplayName ConferenceLocation
# 0                      disc 2014             DISC 2014         Austin, TX
# 1                       esa 2014              ESA 2014    Wrocław, Poland
# 2                            NaN                   NaN                NaN
# 3                            NaN                   NaN                NaN
# 4                            NaN                   NaN                NaN
# ...                          ...                   ...                ...
# 4409807                      NaN                   NaN                NaN
# 4409808                      NaN                   NaN                NaN
# 4409809                      NaN                   NaN                NaN
# 4409810                      NaN                   NaN                NaN
# 4409811                      NaN                   NaN                NaN
#
# [4409812 rows x 15 columns]

# %% [markdown]
# Order by citations count descending to see the articles with the most citations

# %%
# Order by citations count descending to see the articles with the most citations
df_mag_exported_csv = df_mag_exported_csv.sort_values(by='CitationCount', ascending=False)
df_mag_exported_csv.iloc[:5]
# Out:
#          Unnamed: 0     PaperID                           Doi  \
# 4392494     4392498  2194775991          10.1109/CVPR.2016.90
# 176794       176795  2152195021      10.1109/ICNN.1995.488968
# 562266       562267  2161969291         10.1109/CVPR.2005.177
# 3702319     3702323  2108598243     10.1109/CVPR.2009.5206848
# 4005340     4005344  1901129140  10.1007/978-3-319-24574-4_28
#
#                                                 PaperTitle  \
# 4392494       deep residual learning for image recognition
# 176794                         particle swarm optimization
# 562266   histograms of oriented gradients for human det...
# 3702319  imagenet a large scale hierarchical image data...
# 4005340  u net convolutional networks for biomedical im...
#
#                                              OriginalTitle  Year  \
# 4392494       Deep Residual Learning for Image Recognition  2016
# 176794                         Particle swarm optimization  2002
# 562266   Histograms of oriented gradients for human det...  2005
# 3702319  ImageNet: A large-scale hierarchical image dat...  2009
# 4005340  U-Net: Convolutional Networks for Biomedical I...  2015
#
#          ConferenceSeriesID  ConferenceInstanceID  CitationCount  \
# 4392494        1.158168e+09          2.334864e+09          62329
# 176794         1.174935e+09                   NaN          26215
# 562266         1.158168e+09          2.786361e+09          23180
# 3702319        1.158168e+09          1.702096e+08          22980
# 4005340        1.129325e+09          1.333575e+08          20853
#
#          EstimatedCitation ConferenceSeriesNormalizedName  \
# 4392494              75544                           CVPR
# 176794               49377                           ICON
# 562266               36647                           CVPR
# 3702319              28822                           CVPR
# 4005340              26844                         MICCAI
#
#                                ConferenceSeriesDisplayName  \
# 4392494            Computer Vision and Pattern Recognition
# 176794                International Conference on Networks
# 562266             Computer Vision and Pattern Recognition
# 3702319            Computer Vision and Pattern Recognition
# 4005340  Medical Image Computing and Computer-Assisted ...
#
#         ConferenceNormalizedName ConferenceDisplayName      ConferenceLocation
# 4392494                cvpr 2016             CVPR 2016  Las Vegas, Nevada, USA
# 176794                       NaN                   NaN                     NaN
# 562266                 cvpr 2005             CVPR 2005      San Diego, CA, USA
# 3702319                cvpr 2009             CVPR 2009    Miami Beach, Florida
# 4005340              miccai 2015           MICCAI 2015                  Munich
